# %%
import numpy as np
import wandb
import pandas as pd
from tqdm import tqdm

# %%
api = wandb.Api(timeout=600)

# %%
runs = api.runs("inchangbaek4907/scenario")
len(runs)
# Out:
# 233

# %%
runs = list(runs)
runs[:5]
# Out:
# [<Run inchangbaek4907/scenario/re2wd1xx (finished)>,
#  <Run inchangbaek4907/scenario/h5m442q9 (finished)>,
#  <Run inchangbaek4907/scenario/ak7yr998 (finished)>,
#  <Run inchangbaek4907/scenario/mwu8l4yk (finished)>,
#  <Run inchangbaek4907/scenario/7ek9ue01 (finished)>]

# %%
class RunInfo:
    config: dict
    name: str
    run_object: wandb.apis.public.Run
    
    def __init__(self, config, name, run_object):
        self.config = config
        self.name = name
        self.run_object = run_object

    def __str__(self):
        showing_config = dict()
        showing_keys = ['gpt_model']
        
        for key in showing_keys:
            if key in self.config:
                showing_config[key] = self.config[key]
        
        return f"RunInfo(\n\tname={self.name},\n\tconfig={showing_config}\n)"

run_infos = list()

for run in tqdm(runs):
    run_info = RunInfo(config=run.config, name=run.name, run_object=run)
    run_infos.append(run_info)
# Out:
# 100%|██████████| 233/233 [00:00<00:00, 164551.75it/s]

# %%
for run_info in tqdm(run_infos[:]):
    run = run_info.run_object
    
    # if run_info.config['gpt_model'] == 'gpt-4o-multi':
    #     run.config['gpt_model'] = 'gpt-4o'
    #     run.update()
    if run_info.config['gpt_model'] == 'chatgpt-4o':

        run.name = run.name.replace('exp-def', 'exp-chatgpt4o')
        run.config['exp_group'] = run.config['exp_group'].replace('exp-def', 'exp-chatgpt4o')
        run.update()
# Out:
# 100%|██████████| 233/233 [00:37<00:00,  6.23it/s]

# %%
configs = list()
for run_info in tqdm(run_infos[:]):
    configs.append(run_info.config)
    
df = pd.DataFrame(configs)
df
# Out:
# 100%|██████████| 233/233 [00:00<00:00, 862553.25it/s]
#          lr   pe  seed      task  DEBUG  GAMMA  is_3d model  n_eps  n_envs  \
# 0    0.0001  cot     1  scenario   True   0.99  False  conv      2     600
# 1    0.0001  cot     1  scenario   True   0.99  False  conv      2     600
# 2    0.0001  cot     2  scenario   True   0.99  False  conv      2     600
# 3    0.0001  cot     3  scenario   True   0.99  False  conv      2     600
# 4    0.0001  cot     4  scenario   True   0.99  False  conv      2     600
# ..      ...  ...   ...       ...    ...    ...    ...   ...    ...     ...
# 228  0.0001  cot     5  scenario   True   0.99  False  conv      2     600
# 229  0.0001  cot     6  scenario   True   0.99  False  conv      2     600
# 230  0.0001  cot     6  scenario   True   0.99  False  conv      2     600
# 231  0.0001  cot     7  scenario   True   0.99  False  conv      2     600
# 232  0.0001  cot     7  scenario   True   0.99  False  conv      2     600
#
#      ...  n_generation_trials  randomize_map_shape randomize_start_pos  \
# 0    ...                    5                False               False
# 1    ...                    5                False               False
# 2    ...                    5                False               False
# 3    ...                    5                False               False
# 4    ...                    5                False               False
# ..   ...                  ...                  ...                 ...
# 228  ...                    5                False               False
# 229  ...                    5                False               False
# 230  ...                    5                False               False
# 231  ...                    5                False               False
# 232  ...                    5                False               False
#
#      timestep_chunk_size bypass_feedback_path  eval_max_board_scans  \
# 0                     -1                 None                     3
# 1                     -1                 None                     3
# 2                     -1                 None                     3
# 3                     -1                 None                     3
# 4                     -1                 None                     3
# ..                   ...                  ...                   ...
# 228                   -1                 None                     3
# 229                   -1                 None                     3
# 230                   -1                 None                     3
# 231                   -1                 None                     3
# 232                   -1                 None                     3
#
#      reward_function_path eval_randomize_map_shape n_self_alignment  \
# 0                    None                    False              NaN
# 1                    None                    False              NaN
# 2                    None                    False              NaN
# 3                    None                    False              NaN
# 4                    None                    False              NaN
# ..                    ...                      ...              ...
# 228                  None                    False              0.0
# 229                  None                    False              0.0
# 230                  None                    False              0.0
# 231                  None                    False              0.0
# 232                  None                    False              0.0
#
#      feedback_type
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 228        default
# 229        default
# 230        default
# 231        default
# 232        default
#
# [233 rows x 93 columns]

# %%
grouped = df.groupby(['exp_group', 'target_character']).agg({'seed': ['count', 'max']})
grouped.columns = ['count', 'max']
grouped = grouped.reset_index()
grouped
# Out:
#                                    exp_group target_character  count  max
# 0     pe-cot_it-6_fit-hr_exp-chatgpt4o_t-sce                1      5    4
# 1     pe-cot_it-6_fit-hr_exp-chatgpt4o_t-sce                2      8   12
# 2   pe-cot_it-6_fit-hr_exp-chatgpt4osa_t-sce                1      6    6
# 3   pe-cot_it-6_fit-hr_exp-chatgpt4osa_t-sce                2      6    6
# 4           pe-cot_it-6_fit-hr_exp-def_t-sce                1      5    5
# 5           pe-cot_it-6_fit-hr_exp-def_t-sce                2      5    5
# 6      pe-cot_it-6_fit-hr_exp-feedback_t-sce                1      5    5
# 7      pe-cot_it-6_fit-hr_exp-feedback_t-sce                1      5    5
# 8      pe-cot_it-6_fit-hr_exp-feedback_t-sce                2     10    5
# 9   pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs                1     10    7
# 10  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs                2     10    5
# 11        pe-cot_it-6_fit-hr_exp-fs_t-sce_fs                1      7    7
# 12        pe-cot_it-6_fit-hr_exp-fs_t-sce_fs                2      7    7
# 13           pe-cot_it-6_fit-hr_exp-sa_t-sce                1      5    6
# 14           pe-cot_it-6_fit-hr_exp-sa_t-sce                2      5    5
# 15       pe-cot_it-6_fit-hr_exp-vision_t-sce                1      5   12
# 16       pe-cot_it-6_fit-hr_exp-vision_t-sce                2      5   14
# 17    pe-got_it-6_fit-hr_exp-chatgpt4o_t-sce                1      5    5
# 18    pe-got_it-6_fit-hr_exp-chatgpt4o_t-sce                2      5   11
# 19  pe-got_it-6_fit-hr_exp-chatgpt4osa_t-sce                1      6    6
# 20  pe-got_it-6_fit-hr_exp-chatgpt4osa_t-sce                2      6    6
# 21     pe-got_it-6_fit-llm_exp-llmeval_t-sce                1      5    5
# 22     pe-got_it-6_fit-llm_exp-llmeval_t-sce                2      5    4
# 23          pe-got_it-9_fit-hr_exp-def_t-sce                1      8    5
# 24          pe-got_it-9_fit-hr_exp-def_t-sce                2      6    5
# 25           pe-got_it-9_fit-hr_exp-sa_t-sce                1      8    8
# 26           pe-got_it-9_fit-hr_exp-sa_t-sce                2      8    8
# 27    pe-tot_it-6_fit-hr_exp-chatgpt4o_t-sce                1      5    5
# 28    pe-tot_it-6_fit-hr_exp-chatgpt4o_t-sce                2      8   15
# 29  pe-tot_it-6_fit-hr_exp-chatgpt4osa_t-sce                1      6    6
# 30  pe-tot_it-6_fit-hr_exp-chatgpt4osa_t-sce                2      5    6
# 31     pe-tot_it-6_fit-llm_exp-llmeval_t-sce                1      5    5
# 32     pe-tot_it-6_fit-llm_exp-llmeval_t-sce                2      5    5
# 33          pe-tot_it-9_fit-hr_exp-def_t-sce                1      8    5
# 34          pe-tot_it-9_fit-hr_exp-def_t-sce                2      7    5
# 35           pe-tot_it-9_fit-hr_exp-sa_t-sce                1      8    8
# 36           pe-tot_it-9_fit-hr_exp-sa_t-sce                2      5    7

# %%
scarce = grouped[grouped['count'] < 5]
scarce['demand'] = 5 - scarce['count']
scarce
# Out:
# Empty DataFrame
# Columns: [exp_group, target_character, count, max, demand]
# Index: []

# %%
scarce['demand'].sum()
# Out:
# 0

# %%
commands = list()

def get_config(exp_group, target_character):
    return df[(df['exp_group'] == exp_group) & (df['target_character'] == target_character)].iloc[0]

for index, row in scarce.iterrows():
    
    config = get_config(row['exp_group'], row['target_character'])
    
    exp_group = row['exp_group']
    target_character = row['target_character']
    
    
    max_seed = row['max']
    total_iterations = config['total_iterations']
    gpt_model = config['gpt_model']
    exp_name = config['exp_name']
    n_self_alignment = config['n_self_alignment']
    evaluator = config['evaluator']
    pe = config['pe']
    
    # if nan
    if pd.isna(n_self_alignment):

        n_self_alignment = 0
    n_self_alignment = int(n_self_alignment)
    
    # if gpt_model == 'chatgpt-4o':
    #     exp_name = exp_name.replace('def', 'chatgpt4o')
    # 
    for i in range(row['demand']):
        command = f"bash sbatch_gpu.sh experiment.py n_envs=600 wandb_project=scenario task=scenario overwrite=True pe={pe} exp_name={exp_name} gpt_model={gpt_model} total_iterations={total_iterations} seed={max_seed + (i + 1)} evaluator={evaluator} target_character={target_character} n_self_alignment={n_self_alignment}"
        commands.append(command)

commands
# Out:
# []

# %%
commands_block = " \n".join(commands)
from IPython.display import display, Markdown
display(Markdown("```bash\n" + commands_block + ""))
# Out:
# ```bash

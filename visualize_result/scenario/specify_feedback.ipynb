# %%
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
load_dotenv(override=True)
csv_path = os.getenv('CSV_PATH')
csv_path
# Out:
# 'wandb_output_2024-12-25-14-14-59.csv'

# %%
df = pd.read_csv(csv_path)
df = df[df['pe'] == 'cot']
df = df[df['evaluator'] == 'hr']
df = df[df['gpt_model'] == 'gpt-4o']
df = df[df['n_self_alignment'] == 0]
df.reset_index()
# Out:
#      index    run_id                                        final_state  \
# 0        0  re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 1        1  re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 2        2  re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 3        3  re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 4        4  re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# ..     ...       ...                                                ...
# 355   1145  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 356   1146  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 357   1147  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 358   1148  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 359   1149  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
#
#      target_character   pe gpt_model  branch_factor  exp_name evaluator  \
# 0                   1  cot    gpt-4o              2       def        hr
# 1                   1  cot    gpt-4o              2       def        hr
# 2                   1  cot    gpt-4o              2       def        hr
# 3                   1  cot    gpt-4o              2       def        hr
# 4                   1  cot    gpt-4o              2       def        hr
# ..                ...  ...       ...            ...       ...       ...
# 355                 1  cot    gpt-4o              2  feedback        hr
# 356                 1  cot    gpt-4o              2  feedback        hr
# 357                 1  cot    gpt-4o              2  feedback        hr
# 358                 1  cot    gpt-4o              2  feedback        hr
# 359                 1  cot    gpt-4o              2  feedback        hr
#
#      total_iterations  ...  Evaluation/acc_imp_perc Evaluation/exist_imp_perc  \
# 0                   6  ...                 0.011111                  0.533333
# 1                   6  ...                 0.000000                  0.000000
# 2                   6  ...                 0.033333                  0.633333
# 3                   6  ...                 0.000000                  0.600000
# 4                   6  ...                 0.000000                  0.166667
# ..                ...  ...                      ...                       ...
# 355                 6  ...                 0.000000                  0.100000
# 356                 6  ...                 0.000000                  0.033333
# 357                 6  ...                 0.000000                  0.066667
# 358                 6  ...                 0.088889                  0.266667
# 359                 6  ...                 0.000000                  0.666667
#
#      Evaluation/reach_imp_perc Evaluation/path_length  Evaluation/fn_imp_perc  \
# 0                     0.533333              26.000002                2.566667
# 1                     0.000000              26.000000                2.666667
# 2                     0.600000              26.214287                2.566667
# 3                     0.133333               0.000000                3.000000
# 4                     0.000000               0.000000                3.000000
# ..                         ...                    ...                     ...
# 355                   0.000000               0.000000                3.000000
# 356                   0.000000               0.000000                3.000000
# 357                   0.000000               0.000000                3.000000
# 358                   0.166667              26.750000                2.733334
# 359                   0.133333               0.000000                3.000000
#
#     Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  \
# 0                 0.400000                0.000000                0.033333
# 1                 0.333333                0.000000                0.000000
# 2                 0.333333                0.000000                0.100000
# 3                 0.000000                0.000000                0.000000
# 4                 0.000000                0.000000                0.000000
# ..                     ...                     ...                     ...
# 355               0.000000                0.000000                0.000000
# 356               0.000000                0.000000                0.000000
# 357               0.000000                0.000000                0.000000
# 358               0.000000                0.266667                0.000000
# 359               0.000000                0.000000                0.000000
#
#      Evaluation/solvability  Evaluation/playability
# 0                  0.200000                1.000000
# 1                  0.166667                0.966667
# 2                  0.166667                0.933333
# 3                  0.000000                0.000000
# 4                  0.000000                0.000000
# ..                      ...                     ...
# 355                0.000000                0.000000
# 356                0.000000                0.000000
# 357                0.000000                0.000000
# 358                0.133333                0.533333
# 359                0.000000                0.000000
#
# [360 rows x 28 columns]

# %%
df.groupby(['feedback_type', 'pe', 'Evaluation/llm_iteration'])['run_id'].count()
# Out:
# feedback_type  pe   Evaluation/llm_iteration
# default        cot  1                           20
#                     2                           20
#                     3                           20
#                     4                           20
#                     5                           20
#                     6                           20
# generic        cot  1                           20
#                     2                           20
#                     3                           20
#                     4                           20
#                     5                           20
#                     6                           20
# no             cot  1                           20
#                     2                           20
#                     3                           20
#                     4                           20
#                     5                           20
#                     6                           20
# Name: run_id, dtype: int64

# %%
df
# Out:
#         run_id                                        final_state  \
# 0     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 1     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 2     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 3     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 4     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# ...        ...                                                ...
# 1145  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1146  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1147  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1148  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1149  utolklfd  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
#
#       target_character   pe gpt_model  branch_factor  exp_name evaluator  \
# 0                    1  cot    gpt-4o              2       def        hr
# 1                    1  cot    gpt-4o              2       def        hr
# 2                    1  cot    gpt-4o              2       def        hr
# 3                    1  cot    gpt-4o              2       def        hr
# 4                    1  cot    gpt-4o              2       def        hr
# ...                ...  ...       ...            ...       ...       ...
# 1145                 1  cot    gpt-4o              2  feedback        hr
# 1146                 1  cot    gpt-4o              2  feedback        hr
# 1147                 1  cot    gpt-4o              2  feedback        hr
# 1148                 1  cot    gpt-4o              2  feedback        hr
# 1149                 1  cot    gpt-4o              2  feedback        hr
#
#       total_iterations  n_self_alignment  ... Evaluation/acc_imp_perc  \
# 0                    6                 0  ...                0.011111
# 1                    6                 0  ...                0.000000
# 2                    6                 0  ...                0.033333
# 3                    6                 0  ...                0.000000
# 4                    6                 0  ...                0.000000
# ...                ...               ...  ...                     ...
# 1145                 6                 0  ...                0.000000
# 1146                 6                 0  ...                0.000000
# 1147                 6                 0  ...                0.000000
# 1148                 6                 0  ...                0.088889
# 1149                 6                 0  ...                0.000000
#
#       Evaluation/exist_imp_perc Evaluation/reach_imp_perc  \
# 0                      0.533333                  0.533333
# 1                      0.000000                  0.000000
# 2                      0.633333                  0.600000
# 3                      0.600000                  0.133333
# 4                      0.166667                  0.000000
# ...                         ...                       ...
# 1145                   0.100000                  0.000000
# 1146                   0.033333                  0.000000
# 1147                   0.066667                  0.000000
# 1148                   0.266667                  0.166667
# 1149                   0.666667                  0.133333
#
#       Evaluation/path_length Evaluation/fn_imp_perc  Evaluation/fp_imp_perc  \
# 0                  26.000002               2.566667                0.400000
# 1                  26.000000               2.666667                0.333333
# 2                  26.214287               2.566667                0.333333
# 3                   0.000000               3.000000                0.000000
# 4                   0.000000               3.000000                0.000000
# ...                      ...                    ...                     ...
# 1145                0.000000               3.000000                0.000000
# 1146                0.000000               3.000000                0.000000
# 1147                0.000000               3.000000                0.000000
# 1148               26.750000               2.733334                0.000000
# 1149                0.000000               3.000000                0.000000
#
#       Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  Evaluation/solvability  \
# 0                   0.000000                0.033333                0.200000
# 1                   0.000000                0.000000                0.166667
# 2                   0.000000                0.100000                0.166667
# 3                   0.000000                0.000000                0.000000
# 4                   0.000000                0.000000                0.000000
# ...                      ...                     ...                     ...
# 1145                0.000000                0.000000                0.000000
# 1146                0.000000                0.000000                0.000000
# 1147                0.000000                0.000000                0.000000
# 1148                0.266667                0.000000                0.133333
# 1149                0.000000                0.000000                0.000000
#
#       Evaluation/playability
# 0                   1.000000
# 1                   0.966667
# 2                   0.933333
# 3                   0.000000
# 4                   0.000000
# ...                      ...
# 1145                0.000000
# 1146                0.000000
# 1147                0.000000
# 1148                0.533333
# 1149                0.000000
#
# [360 rows x 27 columns]

# %%
sns.barplot(data=df, x='Evaluation/llm_iteration', y='Evaluation/acc_imp_perc', hue="feedback_type")
# Out:
# <Axes: xlabel='Evaluation/llm_iteration', ylabel='Evaluation/acc_imp_perc'>

# %%
import pandas as pd
# 'Evaluation/llm_iteration'을 기준으로 정렬
df = df.sort_values(by=['pe', 'feedback_type', 'Evaluation/llm_iteration'])
df
# Out:
#         run_id                                        final_state  \
# 0     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 6     h5m442q9       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-1
# 12    ak7yr998       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-2
# 18    mwu8l4yk       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-3
# 24    7ek9ue01       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-4
# ...        ...                                                ...
# 1095  6qtlz98j  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1101  dplowae8  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1107  qrhlskys  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1131  5stu1m8l  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1137  v3tnkrsg  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-2...
#
#       target_character   pe gpt_model  branch_factor  exp_name evaluator  \
# 0                    1  cot    gpt-4o              2       def        hr
# 6                    2  cot    gpt-4o              2       def        hr
# 12                   1  cot    gpt-4o              2       def        hr
# 18                   1  cot    gpt-4o              2       def        hr
# 24                   2  cot    gpt-4o              2       def        hr
# ...                ...  ...       ...            ...       ...       ...
# 1095                 2  cot    gpt-4o              2  feedback        hr
# 1101                 2  cot    gpt-4o              2  feedback        hr
# 1107                 2  cot    gpt-4o              2  feedback        hr
# 1131                 1  cot    gpt-4o              2  feedback        hr
# 1137                 2  cot    gpt-4o              2  feedback        hr
#
#       total_iterations  n_self_alignment  ... Evaluation/acc_imp_perc  \
# 0                    6                 0  ...                0.011111
# 6                    6                 0  ...                0.000000
# 12                   6                 0  ...                0.000000
# 18                   6                 0  ...                0.011111
# 24                   6                 0  ...                0.011111
# ...                ...               ...  ...                     ...
# 1095                 6                 0  ...                0.000000
# 1101                 6                 0  ...                0.166667
# 1107                 6                 0  ...                0.000000
# 1131                 6                 0  ...                0.333333
# 1137                 6                 0  ...                0.000000
#
#       Evaluation/exist_imp_perc Evaluation/reach_imp_perc  \
# 0                      0.533333                  0.533333
# 6                      0.416667                  0.050000
# 12                     1.000000                  1.000000
# 18                     0.500000                  0.500000
# 24                     0.766667                  0.216667
# ...                         ...                       ...
# 1095                   0.850000                  0.166667
# 1101                   0.783333                  0.516667
# 1107                   0.850000                  0.133333
# 1131                   1.000000                  1.000000
# 1137                   0.850000                  0.116667
#
#       Evaluation/path_length Evaluation/fn_imp_perc  Evaluation/fp_imp_perc  \
# 0                  26.000002               2.566667                0.400000
# 6                   0.000000               3.000000                0.000000
# 12                 26.000002               3.000000                0.000000
# 18                 26.000002               2.633333                0.333333
# 24                 26.000000               2.966667                0.000000
# ...                      ...                    ...                     ...
# 1095                0.000000               3.000000                0.000000
# 1101               26.526316               2.500000                0.000000
# 1107                0.000000               3.000000                0.000000
# 1131               26.066668               0.000000                2.000000
# 1137                0.000000               3.000000                0.000000
#
#       Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  Evaluation/solvability  \
# 0                   0.000000                0.033333                0.200000
# 6                   0.000000                0.000000                0.000000
# 12                  0.000000                0.000000                0.000000
# 18                  0.000000                0.033333                0.166667
# 24                  0.033333                0.000000                0.000000
# ...                      ...                     ...                     ...
# 1095                0.000000                0.000000                0.000000
# 1101                0.266667                0.233333                0.266667
# 1107                0.000000                0.000000                0.000000
# 1131                0.000000                1.000000                0.966667
# 1137                0.000000                0.000000                0.000000
#
#       Evaluation/playability
# 0                   1.000000
# 6                   0.000000
# 12                  1.000000
# 18                  1.000000
# 24                  0.100000
# ...                      ...
# 1095                0.000000
# 1101                0.633333
# 1107                0.000000
# 1131                1.000000
# 1137                0.000000
#
# [360 rows x 27 columns]

# %%
df
# Out:
#         run_id                                        final_state  \
# 0     re2wd1xx       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1
# 6     h5m442q9       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-1
# 12    ak7yr998       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-2
# 18    mwu8l4yk       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-3
# 24    7ek9ue01       pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-4
# ...        ...                                                ...
# 1095  6qtlz98j  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1101  dplowae8  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1107  qrhlskys  pe-cot_it-6_fit-hr_exp-feedback_t-sce_chr-2_1_...
# 1131  5stu1m8l  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-1...
# 1137  v3tnkrsg  pe-cot_it-6_fit-hr_exp-feedback_t-sce_fs_chr-2...
#
#       target_character   pe gpt_model  branch_factor  exp_name evaluator  \
# 0                    1  cot    gpt-4o              2       def        hr
# 6                    2  cot    gpt-4o              2       def        hr
# 12                   1  cot    gpt-4o              2       def        hr
# 18                   1  cot    gpt-4o              2       def        hr
# 24                   2  cot    gpt-4o              2       def        hr
# ...                ...  ...       ...            ...       ...       ...
# 1095                 2  cot    gpt-4o              2  feedback        hr
# 1101                 2  cot    gpt-4o              2  feedback        hr
# 1107                 2  cot    gpt-4o              2  feedback        hr
# 1131                 1  cot    gpt-4o              2  feedback        hr
# 1137                 2  cot    gpt-4o              2  feedback        hr
#
#       total_iterations  n_self_alignment  ... Evaluation/acc_imp_perc  \
# 0                    6                 0  ...                0.011111
# 6                    6                 0  ...                0.000000
# 12                   6                 0  ...                0.000000
# 18                   6                 0  ...                0.011111
# 24                   6                 0  ...                0.011111
# ...                ...               ...  ...                     ...
# 1095                 6                 0  ...                0.000000
# 1101                 6                 0  ...                0.166667
# 1107                 6                 0  ...                0.000000
# 1131                 6                 0  ...                0.333333
# 1137                 6                 0  ...                0.000000
#
#       Evaluation/exist_imp_perc Evaluation/reach_imp_perc  \
# 0                      0.533333                  0.533333
# 6                      0.416667                  0.050000
# 12                     1.000000                  1.000000
# 18                     0.500000                  0.500000
# 24                     0.766667                  0.216667
# ...                         ...                       ...
# 1095                   0.850000                  0.166667
# 1101                   0.783333                  0.516667
# 1107                   0.850000                  0.133333
# 1131                   1.000000                  1.000000
# 1137                   0.850000                  0.116667
#
#       Evaluation/path_length Evaluation/fn_imp_perc  Evaluation/fp_imp_perc  \
# 0                  26.000002               2.566667                0.400000
# 6                   0.000000               3.000000                0.000000
# 12                 26.000002               3.000000                0.000000
# 18                 26.000002               2.633333                0.333333
# 24                 26.000000               2.966667                0.000000
# ...                      ...                    ...                     ...
# 1095                0.000000               3.000000                0.000000
# 1101               26.526316               2.500000                0.000000
# 1107                0.000000               3.000000                0.000000
# 1131               26.066668               0.000000                2.000000
# 1137                0.000000               3.000000                0.000000
#
#       Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  Evaluation/solvability  \
# 0                   0.000000                0.033333                0.200000
# 6                   0.000000                0.000000                0.000000
# 12                  0.000000                0.000000                0.000000
# 18                  0.000000                0.033333                0.166667
# 24                  0.033333                0.000000                0.000000
# ...                      ...                     ...                     ...
# 1095                0.000000                0.000000                0.000000
# 1101                0.266667                0.233333                0.266667
# 1107                0.000000                0.000000                0.000000
# 1131                0.000000                1.000000                0.966667
# 1137                0.000000                0.000000                0.000000
#
#       Evaluation/playability
# 0                   1.000000
# 6                   0.000000
# 12                  1.000000
# 18                  1.000000
# 24                  0.100000
# ...                      ...
# 1095                0.000000
# 1101                0.633333
# 1107                0.000000
# 1131                1.000000
# 1137                0.000000
#
# [360 rows x 27 columns]

# %%
# 각 'feedback_type' 그룹 내에서 'Evaluation/acc_imp_perc'의 절대값 변화량 계산
df = df.groupby(['pe', 'feedback_type', 'Evaluation/llm_iteration']).agg({'Evaluation/acc_imp_perc': 'mean'}).reset_index()
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc
# 0   cot       default                         1                 0.087778
# 1   cot       default                         2                 0.121111
# 2   cot       default                         3                 0.109444
# 3   cot       default                         4                 0.094444
# 4   cot       default                         5                 0.178333
# 5   cot       default                         6                 0.177222
# 6   cot       generic                         1                 0.054444
# 7   cot       generic                         2                 0.063333
# 8   cot       generic                         3                 0.037778
# 9   cot       generic                         4                 0.031667
# 10  cot       generic                         5                 0.061667
# 11  cot       generic                         6                 0.034444
# 12  cot            no                         1                 0.137222
# 13  cot            no                         2                 0.080000
# 14  cot            no                         3                 0.059444
# 15  cot            no                         4                 0.092222
# 16  cot            no                         5                 0.063889
# 17  cot            no                         6                 0.069444

# %%
df.groupby(['pe', 'feedback_type'])['Evaluation/acc_imp_perc'].diff()
# Out:
# 0          NaN
# 1     0.033333
# 2    -0.011667
# 3    -0.015000
# 4     0.083889
# 5    -0.001111
# 6          NaN
# 7     0.008889
# 8    -0.025556
# 9    -0.006111
# 10    0.030000
# 11   -0.027222
# 12         NaN
# 13   -0.057222
# 14   -0.020556
# 15    0.032778
# 16   -0.028333
# 17    0.005556
# Name: Evaluation/acc_imp_perc, dtype: float64

# %%
df['acc_imp_perc_diff'] = df.groupby(['pe', 'feedback_type'])['Evaluation/acc_imp_perc'].diff()
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc  \
# 0   cot       default                         1                 0.087778
# 1   cot       default                         2                 0.121111
# 2   cot       default                         3                 0.109444
# 3   cot       default                         4                 0.094444
# 4   cot       default                         5                 0.178333
# 5   cot       default                         6                 0.177222
# 6   cot       generic                         1                 0.054444
# 7   cot       generic                         2                 0.063333
# 8   cot       generic                         3                 0.037778
# 9   cot       generic                         4                 0.031667
# 10  cot       generic                         5                 0.061667
# 11  cot       generic                         6                 0.034444
# 12  cot            no                         1                 0.137222
# 13  cot            no                         2                 0.080000
# 14  cot            no                         3                 0.059444
# 15  cot            no                         4                 0.092222
# 16  cot            no                         5                 0.063889
# 17  cot            no                         6                 0.069444
#
#     acc_imp_perc_diff
# 0                 NaN
# 1            0.033333
# 2           -0.011667
# 3           -0.015000
# 4            0.083889
# 5           -0.001111
# 6                 NaN
# 7            0.008889
# 8           -0.025556
# 9           -0.006111
# 10           0.030000
# 11          -0.027222
# 12                NaN
# 13          -0.057222
# 14          -0.020556
# 15           0.032778
# 16          -0.028333
# 17           0.005556

# %%
# sort with feedback type
order = ['no', 'generic', 'default']
df['feedback_type'] = pd.Categorical(df['feedback_type'], categories=order, ordered=True)

# # 지정된 순서에 따라 정렬
df = df.sort_values(by='feedback_type')
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc  \
# 17  cot            no                         6                 0.069444
# 15  cot            no                         4                 0.092222
# 14  cot            no                         3                 0.059444
# 13  cot            no                         2                 0.080000
# 12  cot            no                         1                 0.137222
# 16  cot            no                         5                 0.063889
# 11  cot       generic                         6                 0.034444
# 10  cot       generic                         5                 0.061667
# 9   cot       generic                         4                 0.031667
# 8   cot       generic                         3                 0.037778
# 6   cot       generic                         1                 0.054444
# 7   cot       generic                         2                 0.063333
# 5   cot       default                         6                 0.177222
# 4   cot       default                         5                 0.178333
# 3   cot       default                         4                 0.094444
# 2   cot       default                         3                 0.109444
# 1   cot       default                         2                 0.121111
# 0   cot       default                         1                 0.087778
#
#     acc_imp_perc_diff
# 17           0.005556
# 15           0.032778
# 14          -0.020556
# 13          -0.057222
# 12                NaN
# 16          -0.028333
# 11          -0.027222
# 10           0.030000
# 9           -0.006111
# 8           -0.025556
# 6                 NaN
# 7            0.008889
# 5           -0.001111
# 4            0.083889
# 3           -0.015000
# 2           -0.011667
# 1            0.033333
# 0                 NaN

# %%
pivot_df = df.pivot_table(index=['feedback_type'], columns='Evaluation/llm_iteration', values=['Evaluation/acc_imp_perc'])
pivot_df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_16194/806288370.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_df = df.pivot_table(index=['feedback_type'], columns='Evaluation/llm_iteration', values=['Evaluation/acc_imp_perc'])
#                          Evaluation/acc_imp_perc                      \
# Evaluation/llm_iteration                       1         2         3
# feedback_type
# no                                      0.137222  0.080000  0.059444
# generic                                 0.054444  0.063333  0.037778
# default                                 0.087778  0.121111  0.109444
#
#
# Evaluation/llm_iteration         4         5         6
# feedback_type
# no                        0.092222  0.063889  0.069444
# generic                   0.031667  0.061667  0.034444
# default                   0.094444  0.178333  0.177222

# %%
pivot_df.columns = pd.MultiIndex.from_tuples(
    [('Iteration', f'{i}') for i in range(1, 7)], 
    names=['', '']
)

pivot_df = pivot_df.reset_index()

# %%
# feedback_type 값 교체
pivot_df['feedback_type'] = pivot_df['feedback_type'].replace({
    'no': 'No Feedback',
    'generic': 'Generic',
    'default': 'Specific'
})

pivot_df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_16194/370134405.py:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   pivot_df['feedback_type'] = pivot_df['feedback_type'].replace({
#   feedback_type Iteration
#                         1         2         3         4         5         6
# 0   No Feedback  0.137222  0.080000  0.059444  0.092222  0.063889  0.069444
# 1       Generic  0.054444  0.063333  0.037778  0.031667  0.061667  0.034444
# 2      Specific  0.087778  0.121111  0.109444  0.094444  0.178333  0.177222

# %%
def insert_str(src_str, idx, insert_str):
    # LaTeX 문자열을 줄 단위로 나눔
    lines = src_str.splitlines()
    
    # 지정된 줄 번호 뒤에 \midrule 삽입
    lines.insert(idx, insert_str)
    
    # 다시 LaTeX 문자열로 결합
    return "\n".join(lines)
from IPython.display import display, Latex

# %%
tex_str = pivot_df.to_latex(buf=None, escape=True, bold_rows=False, position='!h', index=False, float_format="%.3f", multicolumn_format='c',
                            caption='Performance between feedback quality type', label='tab:feedback_type')

tex_str = tex_str.replace('feedback_type &', 'Feedback Type &')


tex_str = tex_str.replace('\cline{1-10}\n', '')
tex_str = tex_str.replace('feedback\_type', '\\textbf{Feedback Type}')
tex_str = tex_str.replace('Specific', '\\textbf{Specific}')
tex_str = tex_str.replace('Iteration', 'Iteration ($y_{i}$)')
tex_str = tex_str.replace('\\begin{tabular}{lrrrrrr}', '\\begin{tabular}{l|rrrrrr}')

with open('specify_feedback.tex', 'w') as f:
    f.write(tex_str)
display(Latex(tex_str))
# Out:
# \begin{table}[!h]
# \caption{Performance between feedback quality type}
# \label{tab:feedback_type}
# \begin{tabular}{l|rrrrrr}
# \toprule
# \textbf{Feedback Type} & \multicolumn{6}{c}{Iteration ($y_{i}$)} \\
#  & 1 & 2 & 3 & 4 & 5 & 6 \\
# \midrule
# No Feedback & 0.137 & 0.080 & 0.059 & 0.092 & 0.064 & 0.069 \\
# Generic & 0.054 & 0.063 & 0.038 & 0.032 & 0.062 & 0.034 \\
# \textbf{Specific} & 0.088 & 0.121 & 0.109 & 0.094 & 0.178 & 0.177 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

plt.rcParams['text.usetex'] = True
plt.rc('font', family='Times New Roman')  # Windows의 경우


df = df.sort_values(by='Evaluation/llm_iteration')

# Iteration Labels 설정
iteration_labels = {
    2: r'$\Delta y_{1}\rightarrow{}y_{2}$',
    3: r'$\Delta y_{2}\rightarrow{}y_{3}$',
    4: r'$\Delta y_{3}\rightarrow{}y_{4}$',
    5: r'$\Delta y_{4}\rightarrow{}y_{5}$',
    6: r'$\Delta y_{5}\rightarrow{}y_{6}$',
}

# feedback_type 값 교체
df['feedback_type'] = df['feedback_type'].replace({
    'no': 'No Feedback',
    'generic': 'Generic',
    'default': 'Specific'
})

# 필터링 및 데이터 설정
from_second_df = df[(df['Evaluation/llm_iteration'] >= 2) & (df['Evaluation/llm_iteration'] <= 6)]
from_second_df = from_second_df[from_second_df['pe'] == 'cot']
from_second_df['iteration_label'] = from_second_df['Evaluation/llm_iteration'].map(iteration_labels)

# Barplot 생성
plt.figure(figsize=(5, 3))
ax = sns.barplot(data=from_second_df, x='iteration_label', y='acc_imp_perc_diff',
                 hue="feedback_type", errorbar=None, width=0.7)

# X, Y 범위 설정
ax.set_xlim(-0.5, len(iteration_labels) - 0.5)
ax.set_ylim(-0.077, +0.10)

# 각 막대 위에 bar 색깔과 일치하는 label 표시 (음수는 막대 아래에 표시)
for container in ax.containers:
    for bar in container:
        color = bar.get_facecolor()  # 막대의 색상 가져오기
        value = bar.get_height()     # 막대 높이 (데이터 값)
        label = f"{value:.2f}"       # 라벨 포맷팅
        
        # 위치 조건: 양수면 위에, 음수면 아래에 위치
        y_position = bar.get_height() + 0.005 if value >= 0 else bar.get_height() - 0.005
        
        ax.text(bar.get_x() + bar.get_width() / 2, 
                y_position,  # 조건에 따른 위치 조정
                label,
                ha='center', va='bottom' if value >= 0 else 'top',  # 음수일 경우 va를 top으로
                color=color, fontsize=10)  # 텍스트 색상을 막대 색깔로 설정

# 범례 및 레이블 설정
ax.legend(title='Feedback Type')
plt.xlabel('Iteration')
plt.ylabel(None)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.savefig('specific_feedback.pdf', dpi=300, bbox_inches='tight')
# 그래프 출력
plt.show()

# %%
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
load_dotenv(override=True)
csv_path = os.getenv('CSV_PATH')
csv_path
# Out:
# 'wandb_output_2025-01-02-11-11-34.csv'

# %%
df = pd.read_csv(csv_path)
df = df[df['fewshot'] == False]
df = df[df['pe'] == 'cot']
df = df[df['evaluator'] == 'hr']
df = df[df['gpt_model'] == 'gpt-4o']
df = df[df['n_self_alignment'] == 0]
df.reset_index()
# Out:
#      index    run_id final_state  target_character   pe gpt_model  \
# 0        0  re2wd1xx    finished                 1  cot    gpt-4o
# 1        1  re2wd1xx    finished                 1  cot    gpt-4o
# 2        2  re2wd1xx    finished                 1  cot    gpt-4o
# 3        3  re2wd1xx    finished                 1  cot    gpt-4o
# 4        4  re2wd1xx    finished                 1  cot    gpt-4o
# ..     ...       ...         ...               ...  ...       ...
# 235   1340  qw9aige1    finished                 2  cot    gpt-4o
# 236   1341  qw9aige1    finished                 2  cot    gpt-4o
# 237   1342  qw9aige1    finished                 2  cot    gpt-4o
# 238   1343  qw9aige1    finished                 2  cot    gpt-4o
# 239   1344  qw9aige1    finished                 2  cot    gpt-4o
#
#      branch_factor exp_name evaluator  total_iterations  ...  \
# 0                2      def        hr                 6  ...
# 1                2      def        hr                 6  ...
# 2                2      def        hr                 6  ...
# 3                2      def        hr                 6  ...
# 4                2      def        hr                 6  ...
# ..             ...      ...       ...               ...  ...
# 235              2   vision        hr                 6  ...
# 236              2   vision        hr                 6  ...
# 237              2   vision        hr                 6  ...
# 238              2   vision        hr                 6  ...
# 239              2   vision        hr                 6  ...
#
#      Evaluation/acc_imp_perc Evaluation/exist_imp_perc  \
# 0                   0.011111                  0.533333
# 1                   0.000000                  0.000000
# 2                   0.033333                  0.633333
# 3                   0.000000                  0.600000
# 4                   0.000000                  0.166667
# ..                       ...                       ...
# 235                 0.011111                  0.250000
# 236                 0.155556                  0.950000
# 237                 0.144444                  0.833333
# 238                 0.788889                  0.916667
# 239                 0.711111                  0.950000
#
#     Evaluation/reach_imp_perc  Evaluation/path_length Evaluation/fn_imp_perc  \
# 0                    0.533333               26.000002               2.566667
# 1                    0.000000               26.000000               2.666667
# 2                    0.600000               26.214287               2.566667
# 3                    0.133333                0.000000               3.000000
# 4                    0.000000                0.000000               3.000000
# ..                        ...                     ...                    ...
# 235                  0.016667               27.000000               2.966667
# 236                  0.950000               26.000002               2.533334
# 237                  0.833333               26.000002               2.533334
# 238                  0.916667               26.000002               0.500000
# 239                  0.933333               26.000002               0.800000
#
#      Evaluation/fp_imp_perc Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  \
# 0                  0.400000               0.000000                0.033333
# 1                  0.333333               0.000000                0.000000
# 2                  0.333333               0.000000                0.100000
# 3                  0.000000               0.000000                0.000000
# 4                  0.000000               0.000000                0.000000
# ..                      ...                    ...                     ...
# 235                0.000000               0.033333                0.000000
# 236                0.000000               0.200000                0.266667
# 237                0.033333               0.166667                0.266667
# 238                0.133333               0.766667                1.600000
# 239                0.066667               0.766667                1.366667
#
#      Evaluation/solvability  Evaluation/playability
# 0                  0.200000                1.000000
# 1                  0.166667                0.966667
# 2                  0.166667                0.933333
# 3                  0.000000                0.000000
# 4                  0.000000                0.000000
# ..                      ...                     ...
# 235                0.033333                0.066667
# 236                0.200000                1.000000
# 237                0.200000                1.000000
# 238                0.900000                1.000000
# 239                0.833333                1.000000
#
# [240 rows x 29 columns]

# %%
df.groupby(['feedback_type', 'pe', 'Evaluation/llm_iteration'])['run_id'].count()
# Out:
# feedback_type  pe   Evaluation/llm_iteration
# default        cot  1                           20
#                     2                           20
#                     3                           20
#                     4                           20
#                     5                           20
#                     6                           20
# generic        cot  1                           10
#                     2                           10
#                     3                           10
#                     4                           10
#                     5                           10
#                     6                           10
# no             cot  1                           10
#                     2                           10
#                     3                           10
#                     4                           10
#                     5                           10
#                     6                           10
# Name: run_id, dtype: int64

# %%
df
# Out:
#         run_id final_state  target_character   pe gpt_model  branch_factor  \
# 0     re2wd1xx    finished                 1  cot    gpt-4o              2
# 1     re2wd1xx    finished                 1  cot    gpt-4o              2
# 2     re2wd1xx    finished                 1  cot    gpt-4o              2
# 3     re2wd1xx    finished                 1  cot    gpt-4o              2
# 4     re2wd1xx    finished                 1  cot    gpt-4o              2
# ...        ...         ...               ...  ...       ...            ...
# 1340  qw9aige1    finished                 2  cot    gpt-4o              2
# 1341  qw9aige1    finished                 2  cot    gpt-4o              2
# 1342  qw9aige1    finished                 2  cot    gpt-4o              2
# 1343  qw9aige1    finished                 2  cot    gpt-4o              2
# 1344  qw9aige1    finished                 2  cot    gpt-4o              2
#
#      exp_name evaluator  total_iterations  n_self_alignment  ...  \
# 0         def        hr                 6                 0  ...
# 1         def        hr                 6                 0  ...
# 2         def        hr                 6                 0  ...
# 3         def        hr                 6                 0  ...
# 4         def        hr                 6                 0  ...
# ...       ...       ...               ...               ...  ...
# 1340   vision        hr                 6                 0  ...
# 1341   vision        hr                 6                 0  ...
# 1342   vision        hr                 6                 0  ...
# 1343   vision        hr                 6                 0  ...
# 1344   vision        hr                 6                 0  ...
#
#      Evaluation/acc_imp_perc Evaluation/exist_imp_perc  \
# 0                   0.011111                  0.533333
# 1                   0.000000                  0.000000
# 2                   0.033333                  0.633333
# 3                   0.000000                  0.600000
# 4                   0.000000                  0.166667
# ...                      ...                       ...
# 1340                0.011111                  0.250000
# 1341                0.155556                  0.950000
# 1342                0.144444                  0.833333
# 1343                0.788889                  0.916667
# 1344                0.711111                  0.950000
#
#       Evaluation/reach_imp_perc Evaluation/path_length  \
# 0                      0.533333              26.000002
# 1                      0.000000              26.000000
# 2                      0.600000              26.214287
# 3                      0.133333               0.000000
# 4                      0.000000               0.000000
# ...                         ...                    ...
# 1340                   0.016667              27.000000
# 1341                   0.950000              26.000002
# 1342                   0.833333              26.000002
# 1343                   0.916667              26.000002
# 1344                   0.933333              26.000002
#
#       Evaluation/fn_imp_perc Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  \
# 0                   2.566667               0.400000                0.000000
# 1                   2.666667               0.333333                0.000000
# 2                   2.566667               0.333333                0.000000
# 3                   3.000000               0.000000                0.000000
# 4                   3.000000               0.000000                0.000000
# ...                      ...                    ...                     ...
# 1340                2.966667               0.000000                0.033333
# 1341                2.533334               0.000000                0.200000
# 1342                2.533334               0.033333                0.166667
# 1343                0.500000               0.133333                0.766667
# 1344                0.800000               0.066667                0.766667
#
#       Evaluation/tp_imp_perc  Evaluation/solvability  Evaluation/playability
# 0                   0.033333                0.200000                1.000000
# 1                   0.000000                0.166667                0.966667
# 2                   0.100000                0.166667                0.933333
# 3                   0.000000                0.000000                0.000000
# 4                   0.000000                0.000000                0.000000
# ...                      ...                     ...                     ...
# 1340                0.000000                0.033333                0.066667
# 1341                0.266667                0.200000                1.000000
# 1342                0.266667                0.200000                1.000000
# 1343                1.600000                0.900000                1.000000
# 1344                1.366667                0.833333                1.000000
#
# [240 rows x 28 columns]

# %%
sns.barplot(data=df, x='Evaluation/llm_iteration', y='Evaluation/acc_imp_perc', hue="feedback_type")
# Out:
# <Axes: xlabel='Evaluation/llm_iteration', ylabel='Evaluation/acc_imp_perc'>

# %%
import pandas as pd
# 'Evaluation/llm_iteration'을 기준으로 정렬
df = df.sort_values(by=['pe', 'feedback_type', 'Evaluation/llm_iteration'])
df
# Out:
#         run_id final_state  target_character   pe gpt_model  branch_factor  \
# 0     re2wd1xx    finished                 1  cot    gpt-4o              2
# 6     h5m442q9    finished                 2  cot    gpt-4o              2
# 12    ak7yr998    finished                 1  cot    gpt-4o              2
# 18    mwu8l4yk    finished                 1  cot    gpt-4o              2
# 24    7ek9ue01    finished                 2  cot    gpt-4o              2
# ...        ...         ...               ...  ...       ...            ...
# 987   a34qlddz    finished                 2  cot    gpt-4o              2
# 999   wgj0cz82    finished                 2  cot    gpt-4o              2
# 1011  6qtlz98j    finished                 2  cot    gpt-4o              2
# 1017  dplowae8    finished                 2  cot    gpt-4o              2
# 1023  qrhlskys    finished                 2  cot    gpt-4o              2
#
#       exp_name evaluator  total_iterations  n_self_alignment  ...  \
# 0          def        hr                 6                 0  ...
# 6          def        hr                 6                 0  ...
# 12         def        hr                 6                 0  ...
# 18         def        hr                 6                 0  ...
# 24         def        hr                 6                 0  ...
# ...        ...       ...               ...               ...  ...
# 987   feedback        hr                 6                 0  ...
# 999   feedback        hr                 6                 0  ...
# 1011  feedback        hr                 6                 0  ...
# 1017  feedback        hr                 6                 0  ...
# 1023  feedback        hr                 6                 0  ...
#
#      Evaluation/acc_imp_perc Evaluation/exist_imp_perc  \
# 0                   0.011111                  0.533333
# 6                   0.000000                  0.416667
# 12                  0.000000                  1.000000
# 18                  0.011111                  0.500000
# 24                  0.011111                  0.766667
# ...                      ...                       ...
# 987                 0.077778                  0.700000
# 999                 0.000000                  0.750000
# 1011                0.000000                  0.850000
# 1017                0.166667                  0.783333
# 1023                0.000000                  0.850000
#
#       Evaluation/reach_imp_perc Evaluation/path_length  \
# 0                      0.533333              26.000002
# 6                      0.050000               0.000000
# 12                     1.000000              26.000002
# 18                     0.500000              26.000002
# 24                     0.216667              26.000000
# ...                         ...                    ...
# 987                    0.316667              26.153847
# 999                    0.166667              27.000000
# 1011                   0.166667               0.000000
# 1017                   0.516667              26.526316
# 1023                   0.133333               0.000000
#
#       Evaluation/fn_imp_perc Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  \
# 0                   2.566667               0.400000                0.000000
# 6                   3.000000               0.000000                0.000000
# 12                  3.000000               0.000000                0.000000
# 18                  2.633333               0.333333                0.000000
# 24                  2.966667               0.000000                0.033333
# ...                      ...                    ...                     ...
# 987                 2.766667               0.000000                0.133333
# 999                 3.000000               0.000000                0.000000
# 1011                3.000000               0.000000                0.000000
# 1017                2.500000               0.000000                0.266667
# 1023                3.000000               0.000000                0.000000
#
#       Evaluation/tp_imp_perc  Evaluation/solvability  Evaluation/playability
# 0                   0.033333                0.200000                1.000000
# 6                   0.000000                0.000000                0.000000
# 12                  0.000000                0.000000                1.000000
# 18                  0.033333                0.166667                1.000000
# 24                  0.000000                0.000000                0.100000
# ...                      ...                     ...                     ...
# 987                 0.100000                0.133333                0.433333
# 999                 0.000000                0.000000                0.066667
# 1011                0.000000                0.000000                0.000000
# 1017                0.233333                0.266667                0.633333
# 1023                0.000000                0.000000                0.000000
#
# [240 rows x 28 columns]

# %%
df
# Out:
#         run_id final_state  target_character   pe gpt_model  branch_factor  \
# 0     re2wd1xx    finished                 1  cot    gpt-4o              2
# 6     h5m442q9    finished                 2  cot    gpt-4o              2
# 12    ak7yr998    finished                 1  cot    gpt-4o              2
# 18    mwu8l4yk    finished                 1  cot    gpt-4o              2
# 24    7ek9ue01    finished                 2  cot    gpt-4o              2
# ...        ...         ...               ...  ...       ...            ...
# 987   a34qlddz    finished                 2  cot    gpt-4o              2
# 999   wgj0cz82    finished                 2  cot    gpt-4o              2
# 1011  6qtlz98j    finished                 2  cot    gpt-4o              2
# 1017  dplowae8    finished                 2  cot    gpt-4o              2
# 1023  qrhlskys    finished                 2  cot    gpt-4o              2
#
#       exp_name evaluator  total_iterations  n_self_alignment  ...  \
# 0          def        hr                 6                 0  ...
# 6          def        hr                 6                 0  ...
# 12         def        hr                 6                 0  ...
# 18         def        hr                 6                 0  ...
# 24         def        hr                 6                 0  ...
# ...        ...       ...               ...               ...  ...
# 987   feedback        hr                 6                 0  ...
# 999   feedback        hr                 6                 0  ...
# 1011  feedback        hr                 6                 0  ...
# 1017  feedback        hr                 6                 0  ...
# 1023  feedback        hr                 6                 0  ...
#
#      Evaluation/acc_imp_perc Evaluation/exist_imp_perc  \
# 0                   0.011111                  0.533333
# 6                   0.000000                  0.416667
# 12                  0.000000                  1.000000
# 18                  0.011111                  0.500000
# 24                  0.011111                  0.766667
# ...                      ...                       ...
# 987                 0.077778                  0.700000
# 999                 0.000000                  0.750000
# 1011                0.000000                  0.850000
# 1017                0.166667                  0.783333
# 1023                0.000000                  0.850000
#
#       Evaluation/reach_imp_perc Evaluation/path_length  \
# 0                      0.533333              26.000002
# 6                      0.050000               0.000000
# 12                     1.000000              26.000002
# 18                     0.500000              26.000002
# 24                     0.216667              26.000000
# ...                         ...                    ...
# 987                    0.316667              26.153847
# 999                    0.166667              27.000000
# 1011                   0.166667               0.000000
# 1017                   0.516667              26.526316
# 1023                   0.133333               0.000000
#
#       Evaluation/fn_imp_perc Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  \
# 0                   2.566667               0.400000                0.000000
# 6                   3.000000               0.000000                0.000000
# 12                  3.000000               0.000000                0.000000
# 18                  2.633333               0.333333                0.000000
# 24                  2.966667               0.000000                0.033333
# ...                      ...                    ...                     ...
# 987                 2.766667               0.000000                0.133333
# 999                 3.000000               0.000000                0.000000
# 1011                3.000000               0.000000                0.000000
# 1017                2.500000               0.000000                0.266667
# 1023                3.000000               0.000000                0.000000
#
#       Evaluation/tp_imp_perc  Evaluation/solvability  Evaluation/playability
# 0                   0.033333                0.200000                1.000000
# 6                   0.000000                0.000000                0.000000
# 12                  0.000000                0.000000                1.000000
# 18                  0.033333                0.166667                1.000000
# 24                  0.000000                0.000000                0.100000
# ...                      ...                     ...                     ...
# 987                 0.100000                0.133333                0.433333
# 999                 0.000000                0.000000                0.066667
# 1011                0.000000                0.000000                0.000000
# 1017                0.233333                0.266667                0.633333
# 1023                0.000000                0.000000                0.000000
#
# [240 rows x 28 columns]

# %%
# 각 'feedback_type' 그룹 내에서 'Evaluation/acc_imp_perc'의 절대값 변화량 계산
df = df.groupby(['pe', 'feedback_type', 'Evaluation/llm_iteration']).agg({'Evaluation/acc_imp_perc': 'mean'}).reset_index()
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc
# 0   cot       default                         1                 0.032222
# 1   cot       default                         2                 0.014444
# 2   cot       default                         3                 0.075000
# 3   cot       default                         4                 0.072222
# 4   cot       default                         5                 0.142222
# 5   cot       default                         6                 0.156111
# 6   cot       generic                         1                 0.034444
# 7   cot       generic                         2                 0.033333
# 8   cot       generic                         3                 0.052222
# 9   cot       generic                         4                 0.038889
# 10  cot       generic                         5                 0.017778
# 11  cot       generic                         6                 0.031111
# 12  cot            no                         1                 0.085556
# 13  cot            no                         2                 0.063333
# 14  cot            no                         3                 0.071111
# 15  cot            no                         4                 0.087778
# 16  cot            no                         5                 0.092222
# 17  cot            no                         6                 0.098889

# %%
df.groupby(['pe', 'feedback_type'])['Evaluation/acc_imp_perc'].diff()
# Out:
# 0          NaN
# 1    -0.017778
# 2     0.060556
# 3    -0.002778
# 4     0.070000
# 5     0.013889
# 6          NaN
# 7    -0.001111
# 8     0.018889
# 9    -0.013333
# 10   -0.021111
# 11    0.013333
# 12         NaN
# 13   -0.022222
# 14    0.007778
# 15    0.016667
# 16    0.004444
# 17    0.006667
# Name: Evaluation/acc_imp_perc, dtype: float64

# %%
df['acc_imp_perc_diff'] = df.groupby(['pe', 'feedback_type'])['Evaluation/acc_imp_perc'].diff()
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc  \
# 0   cot       default                         1                 0.032222
# 1   cot       default                         2                 0.014444
# 2   cot       default                         3                 0.075000
# 3   cot       default                         4                 0.072222
# 4   cot       default                         5                 0.142222
# 5   cot       default                         6                 0.156111
# 6   cot       generic                         1                 0.034444
# 7   cot       generic                         2                 0.033333
# 8   cot       generic                         3                 0.052222
# 9   cot       generic                         4                 0.038889
# 10  cot       generic                         5                 0.017778
# 11  cot       generic                         6                 0.031111
# 12  cot            no                         1                 0.085556
# 13  cot            no                         2                 0.063333
# 14  cot            no                         3                 0.071111
# 15  cot            no                         4                 0.087778
# 16  cot            no                         5                 0.092222
# 17  cot            no                         6                 0.098889
#
#     acc_imp_perc_diff
# 0                 NaN
# 1           -0.017778
# 2            0.060556
# 3           -0.002778
# 4            0.070000
# 5            0.013889
# 6                 NaN
# 7           -0.001111
# 8            0.018889
# 9           -0.013333
# 10          -0.021111
# 11           0.013333
# 12                NaN
# 13          -0.022222
# 14           0.007778
# 15           0.016667
# 16           0.004444
# 17           0.006667

# %%
# sort with feedback type
order = ['no', 'generic', 'default']
df['feedback_type'] = pd.Categorical(df['feedback_type'], categories=order, ordered=True)

# # 지정된 순서에 따라 정렬
df = df.sort_values(by='feedback_type')
df
# Out:
#      pe feedback_type  Evaluation/llm_iteration  Evaluation/acc_imp_perc  \
# 17  cot            no                         6                 0.098889
# 15  cot            no                         4                 0.087778
# 14  cot            no                         3                 0.071111
# 13  cot            no                         2                 0.063333
# 12  cot            no                         1                 0.085556
# 16  cot            no                         5                 0.092222
# 11  cot       generic                         6                 0.031111
# 10  cot       generic                         5                 0.017778
# 9   cot       generic                         4                 0.038889
# 8   cot       generic                         3                 0.052222
# 6   cot       generic                         1                 0.034444
# 7   cot       generic                         2                 0.033333
# 5   cot       default                         6                 0.156111
# 4   cot       default                         5                 0.142222
# 3   cot       default                         4                 0.072222
# 2   cot       default                         3                 0.075000
# 1   cot       default                         2                 0.014444
# 0   cot       default                         1                 0.032222
#
#     acc_imp_perc_diff
# 17           0.006667
# 15           0.016667
# 14           0.007778
# 13          -0.022222
# 12                NaN
# 16           0.004444
# 11           0.013333
# 10          -0.021111
# 9           -0.013333
# 8            0.018889
# 6                 NaN
# 7           -0.001111
# 5            0.013889
# 4            0.070000
# 3           -0.002778
# 2            0.060556
# 1           -0.017778
# 0                 NaN

# %%
pivot_df = df.pivot_table(index=['feedback_type'], columns='Evaluation/llm_iteration', values=['Evaluation/acc_imp_perc'])
pivot_df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_90104/806288370.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_df = df.pivot_table(index=['feedback_type'], columns='Evaluation/llm_iteration', values=['Evaluation/acc_imp_perc'])
#                          Evaluation/acc_imp_perc                      \
# Evaluation/llm_iteration                       1         2         3
# feedback_type
# no                                      0.085556  0.063333  0.071111
# generic                                 0.034444  0.033333  0.052222
# default                                 0.032222  0.014444  0.075000
#
#
# Evaluation/llm_iteration         4         5         6
# feedback_type
# no                        0.087778  0.092222  0.098889
# generic                   0.038889  0.017778  0.031111
# default                   0.072222  0.142222  0.156111

# %%
pivot_df.columns = pd.MultiIndex.from_tuples(
    [('Iteration', f'{i}') for i in range(1, 7)], 
    names=['', '']
)

pivot_df = pivot_df.reset_index()

# %%
# feedback_type 값 교체
pivot_df['feedback_type'] = pivot_df['feedback_type'].replace({
    'no': 'No Feedback',
    'generic': 'Generic',
    'default': 'Specific'
})

pivot_df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_90104/370134405.py:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   pivot_df['feedback_type'] = pivot_df['feedback_type'].replace({
#   feedback_type Iteration
#                         1         2         3         4         5         6
# 0   No Feedback  0.085556  0.063333  0.071111  0.087778  0.092222  0.098889
# 1       Generic  0.034444  0.033333  0.052222  0.038889  0.017778  0.031111
# 2      Specific  0.032222  0.014444  0.075000  0.072222  0.142222  0.156111

# %%
def insert_str(src_str, idx, insert_str):
    # LaTeX 문자열을 줄 단위로 나눔
    lines = src_str.splitlines()
    
    # 지정된 줄 번호 뒤에 \midrule 삽입
    lines.insert(idx, insert_str)
    
    # 다시 LaTeX 문자열로 결합
    return "\n".join(lines)
from IPython.display import display, Latex

# %%
tex_str = pivot_df.to_latex(buf=None, escape=True, bold_rows=False, position='!h', index=False, float_format="%.3f", multicolumn_format='c',
                            caption='Performance between feedback quality type', label='tab:feedback_type')

tex_str = tex_str.replace('feedback_type &', 'Feedback Type &')


tex_str = tex_str.replace('\cline{1-10}\n', '')
tex_str = tex_str.replace('feedback\_type', '\\textbf{Feedback Type}')
tex_str = tex_str.replace('Specific', '\\textbf{Specific}')
tex_str = tex_str.replace('Iteration', 'Iteration ($y_{i}$)')
tex_str = tex_str.replace('\\begin{tabular}{lrrrrrr}', '\\begin{tabular}{l|rrrrrr}')

with open('specify_feedback.tex', 'w') as f:
    f.write(tex_str)
display(Latex(tex_str))
# Out:
# \begin{table}[!h]
# \caption{Performance between feedback quality type}
# \label{tab:feedback_type}
# \begin{tabular}{l|rrrrrr}
# \toprule
# \textbf{Feedback Type} & \multicolumn{6}{c}{Iteration ($y_{i}$)} \\
#  & 1 & 2 & 3 & 4 & 5 & 6 \\
# \midrule
# No Feedback & 0.086 & 0.063 & 0.071 & 0.088 & 0.092 & 0.099 \\
# Generic & 0.034 & 0.033 & 0.052 & 0.039 & 0.018 & 0.031 \\
# \textbf{Specific} & 0.032 & 0.014 & 0.075 & 0.072 & 0.142 & 0.156 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

plt.rcParams['text.usetex'] = True
plt.rc('font', family='Times New Roman')  # Windows의 경우


df = df.sort_values(by='Evaluation/llm_iteration')

# Iteration Labels 설정
iteration_labels = {
    2: r'$\Delta y_{1}\rightarrow{}y_{2}$',
    3: r'$\Delta y_{2}\rightarrow{}y_{3}$',
    4: r'$\Delta y_{3}\rightarrow{}y_{4}$',
    5: r'$\Delta y_{4}\rightarrow{}y_{5}$',
    6: r'$\Delta y_{5}\rightarrow{}y_{6}$',
}

# feedback_type 값 교체
df['feedback_type'] = df['feedback_type'].replace({
    'no': 'No Feedback',
    'generic': 'Generic',
    'default': 'Specific'
})

# 필터링 및 데이터 설정
from_second_df = df[(df['Evaluation/llm_iteration'] >= 2) & (df['Evaluation/llm_iteration'] <= 6)]
from_second_df = from_second_df[from_second_df['pe'] == 'cot']
from_second_df['iteration_label'] = from_second_df['Evaluation/llm_iteration'].map(iteration_labels)

# Barplot 생성
plt.figure(figsize=(5, 3.5))
ax = sns.barplot(data=from_second_df, x='iteration_label', y='acc_imp_perc_diff',
                 hue="feedback_type", errorbar=None, width=0.7)

# X, Y 범위 설정
ax.set_xlim(-0.5, len(iteration_labels) - 0.5)
ax.set_ylim(-0.03, +0.08)

# 각 막대 위에 bar 색깔과 일치하는 label 표시 (음수는 막대 아래에 표시)
for container in ax.containers:
    for bar in container:
        color = bar.get_facecolor()  # 막대의 색상 가져오기
        value = bar.get_height()     # 막대 높이 (데이터 값)
        label = f"{value:.2f}"       # 라벨 포맷팅
        
        # 위치 조건: 양수면 위에, 음수면 아래에 위치
        y_position = bar.get_height() + 0.003 if value >= 0 else bar.get_height() - 0.003
        
        ax.text(bar.get_x() + bar.get_width() / 2, 
                y_position,  # 조건에 따른 위치 조정
                label,
                ha='center', va='bottom' if value >= 0 else 'top',  # 음수일 경우 va를 top으로
                color=color, fontsize=10)  # 텍스트 색상을 막대 색깔로 설정

# 범례 및 레이블 설정
ax.legend(title='Feedback Type', loc='upper left', title_fontsize=8, fontsize=7)
plt.xlabel('Iteration')
plt.ylabel(None)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.savefig('specific_feedback.pdf', dpi=300, bbox_inches='tight')
# 그래프 출력
plt.show()
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_90104/3709485200.py:21: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['feedback_type'] = df['feedback_type'].replace({

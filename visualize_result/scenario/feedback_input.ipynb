# %%
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
load_dotenv(override=True)
csv_path = os.getenv('CSV_PATH')
csv_path
# Out:
# 'wandb_output_2024-12-25-14-14-59.csv'

# %%
df = pd.read_csv(csv_path)
df.describe()
# Out:
#        target_character  branch_factor  total_iterations  n_self_alignment  \
# count       1150.000000         1150.0       1150.000000       1150.000000
# mean           1.481739            2.0          7.153043          1.047826
# std            0.499884            0.0          1.459957          2.035877
# min            1.000000            2.0          6.000000          0.000000
# 25%            1.000000            2.0          6.000000          0.000000
# 50%            1.000000            2.0          6.000000          0.000000
# 75%            2.000000            2.0          9.000000          0.000000
# max            2.000000            2.0          9.000000          5.000000
#
#        total_timesteps         seed  Evaluation/llm_iteration  \
# count     1.150000e+03  1150.000000               1150.000000
# mean      4.895652e+07     3.513913                  3.861739
# std       6.378531e+06     1.748623                  2.051346
# min       1.000000e+07     1.000000                  1.000000
# 25%       5.000000e+07     2.000000                  2.000000
# 50%       5.000000e+07     4.000000                  4.000000
# 75%       5.000000e+07     5.000000                  5.000000
# max       5.000000e+07     8.000000                  9.000000
#
#        Evaluation/acc_imp_perc  Evaluation/exist_imp_perc  \
# count              1150.000000                1150.000000
# mean                  0.136309                   0.649101
# std                   0.243482                   0.300190
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.466667
# 50%                   0.011111                   0.700000
# 75%                   0.133333                   0.933333
# max                   1.000000                   1.000000
#
#        Evaluation/reach_imp_perc  Evaluation/path_length  \
# count                1150.000000             1150.000000
# mean                    0.411348               19.330417
# std                     0.341956               11.857983
# min                     0.000000                0.000000
# 25%                     0.116667                0.000000
# 50%                     0.316667               26.000002
# 75%                     0.666667               26.400000
# max                     1.000000               33.000000
#
#        Evaluation/fn_imp_perc  Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  \
# count             1150.000000             1150.000000             1150.000000
# mean                 2.404957                0.186116                0.149043
# std                  0.927094                0.384427                0.341443
# min                  0.000000                0.000000                0.000000
# 25%                  2.333333                0.000000                0.000000
# 50%                  2.866667                0.000000                0.000000
# 75%                  3.000000                0.200000                0.100000
# max                  3.000000                2.000000                2.000000
#
#        Evaluation/tp_imp_perc  Evaluation/solvability  Evaluation/playability
# count             1150.000000             1150.000000             1150.000000
# mean                 0.259884                0.229101                0.503188
# std                  0.512099                0.336054                0.440814
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.066667                0.466667
# 75%                  0.200000                0.266667                1.000000
# max                  2.000000                1.000000                1.000000

# %%
df.columns
# Out:
# Index(['run_id', 'final_state', 'target_character', 'pe', 'gpt_model',
#        'branch_factor', 'exp_name', 'evaluator', 'total_iterations',
#        'n_self_alignment', 'feedback_type', 'total_timesteps',
#        'reward_feature', 'fewshot', 'problem', 'seed',
#        'Evaluation/llm_iteration', 'Evaluation/acc_imp_perc',
#        'Evaluation/exist_imp_perc', 'Evaluation/reach_imp_perc',
#        'Evaluation/path_length', 'Evaluation/fn_imp_perc',
#        'Evaluation/fp_imp_perc', 'Evaluation/tn_imp_perc',
#        'Evaluation/tp_imp_perc', 'Evaluation/solvability',
#        'Evaluation/playability'],
#       dtype='object')

# %%
df = df[df['fewshot'] == False]
df = df[df['feedback_type'] == 'default']
df = df[df['n_self_alignment'] == 0]
df = df[df['evaluator'] == 'hr']
df = df[df['gpt_model'] == 'gpt-4o']
df = df[df['pe'].isin(['cot'])]
df
# Out:
#        run_id                                   final_state  target_character  \
# 0    re2wd1xx  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1                 1
# 1    re2wd1xx  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1                 1
# 2    re2wd1xx  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1                 1
# 3    re2wd1xx  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1                 1
# 4    re2wd1xx  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-1_1_s-1                 1
# ..        ...                                           ...               ...
# 965  01vofhsc  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-5                 2
# 966  01vofhsc  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-5                 2
# 967  01vofhsc  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-5                 2
# 968  01vofhsc  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-5                 2
# 969  01vofhsc  pe-cot_it-6_fit-hr_exp-def_t-sce_chr-2_1_s-5                 2
#
#       pe gpt_model  branch_factor exp_name evaluator  total_iterations  \
# 0    cot    gpt-4o              2      def        hr                 6
# 1    cot    gpt-4o              2      def        hr                 6
# 2    cot    gpt-4o              2      def        hr                 6
# 3    cot    gpt-4o              2      def        hr                 6
# 4    cot    gpt-4o              2      def        hr                 6
# ..   ...       ...            ...      ...       ...               ...
# 965  cot    gpt-4o              2      def        hr                 6
# 966  cot    gpt-4o              2      def        hr                 6
# 967  cot    gpt-4o              2      def        hr                 6
# 968  cot    gpt-4o              2      def        hr                 6
# 969  cot    gpt-4o              2      def        hr                 6
#
#      n_self_alignment  ... Evaluation/acc_imp_perc  Evaluation/exist_imp_perc  \
# 0                   0  ...                0.011111                   0.533333
# 1                   0  ...                0.000000                   0.000000
# 2                   0  ...                0.033333                   0.633333
# 3                   0  ...                0.000000                   0.600000
# 4                   0  ...                0.000000                   0.166667
# ..                ...  ...                     ...                        ...
# 965                 0  ...                0.000000                   0.483333
# 966                 0  ...                0.488889                   1.000000
# 967                 0  ...                0.577778                   1.000000
# 968                 0  ...                0.577778                   1.000000
# 969                 0  ...                0.533333                   1.000000
#
#     Evaluation/reach_imp_perc  Evaluation/path_length Evaluation/fn_imp_perc  \
# 0                    0.533333               26.000002               2.566667
# 1                    0.000000               26.000000               2.666667
# 2                    0.600000               26.214287               2.566667
# 3                    0.133333                0.000000               3.000000
# 4                    0.000000                0.000000               3.000000
# ..                        ...                     ...                    ...
# 965                  0.033333                0.000000               3.000000
# 966                  0.916667               27.000000               0.800000
# 967                  0.950000               26.692308               0.400000
# 968                  0.966667               27.230770               0.400000
# 969                  0.916667               27.166668               0.600000
#
#      Evaluation/fp_imp_perc  Evaluation/tn_imp_perc  Evaluation/tp_imp_perc  \
# 0                  0.400000                     0.0                0.033333
# 1                  0.333333                     0.0                0.000000
# 2                  0.333333                     0.0                0.100000
# 3                  0.000000                     0.0                0.000000
# 4                  0.000000                     0.0                0.000000
# ..                      ...                     ...                     ...
# 965                0.000000                     0.0                0.000000
# 966                0.733333                     0.0                1.466667
# 967                0.866667                     0.0                1.733333
# 968                0.866667                     0.0                1.733333
# 969                0.800000                     0.0                1.600000
#
#      Evaluation/solvability  Evaluation/playability
# 0                  0.200000                1.000000
# 1                  0.166667                0.966667
# 2                  0.166667                0.933333
# 3                  0.000000                0.000000
# 4                  0.000000                0.000000
# ..                      ...                     ...
# 965                0.000000                0.000000
# 966                0.733333                0.733333
# 967                0.833333                0.866667
# 968                0.800000                0.866667
# 969                0.800000                0.800000
#
# [120 rows x 27 columns]

# %%
df.groupby(['gpt_model', 'pe', 'exp_name']).agg({'Evaluation/acc_imp_perc': ['count']})
# Out:
#                        Evaluation/acc_imp_perc
#                                          count
# gpt_model pe  exp_name
# gpt-4o    cot def                           60
#               vision                        60

# %%
base_df = df[(df['Evaluation/llm_iteration'] == 1)]
base_df = base_df.groupby(['gpt_model', 'pe', 'exp_name']).agg({'Evaluation/acc_imp_perc': ['mean']})
base_df.columns = ['Base']
base_df = base_df.reset_index()
base_df
# Out:
#   gpt_model   pe exp_name      Base
# 0    gpt-4o  cot      def  0.033333
# 1    gpt-4o  cot   vision  0.142222

# %%
fb_df = df[(df['Evaluation/llm_iteration'] == 6)]
fb_df = fb_df.groupby(['gpt_model', 'pe', 'exp_name']).agg({'Evaluation/acc_imp_perc': ['mean']})
fb_df.columns = ['+ Feedback']
fb_df = fb_df.reset_index()
fb_df
# Out:
#   gpt_model   pe exp_name  + Feedback
# 0    gpt-4o  cot      def    0.155556
# 1    gpt-4o  cot   vision    0.198889

# %%
pk = ['gpt_model', 'pe', 'exp_name']

result = pd.merge(base_df, fb_df, on=pk)
result['Delta'] = result['+ Feedback'] - result['Base']

result
# Out:
#   gpt_model   pe exp_name      Base  + Feedback     Delta
# 0    gpt-4o  cot      def  0.033333    0.155556  0.122222
# 1    gpt-4o  cot   vision  0.142222    0.198889  0.056667

# %%
pe_order = ["cot"]  # 예: Prompt Engineering 방식

result['pe'] = pd.Categorical(result['pe'], categories=pe_order, ordered=True)


pivot_df = result.pivot_table(index=['pe'], columns='exp_name', values=['Base', '+ Feedback', 'Delta'])
pivot_df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_78596/472322549.py:6: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_df = result.pivot_table(index=['pe'], columns='exp_name', values=['Base', '+ Feedback', 'Delta'])
#          + Feedback                Base               Delta
# exp_name        def    vision       def    vision       def    vision
# pe
# cot        0.155556  0.198889  0.033333  0.142222  0.122222  0.056667

# %%
pivot_df.columns = pivot_df.columns.swaplevel(0, 1)
pivot_df.columns
# Out:
# MultiIndex([(   'def', '+ Feedback'),
#             ('vision', '+ Feedback'),
#             (   'def',       'Base'),
#             ('vision',       'Base'),
#             (   'def',      'Delta'),
#             ('vision',      'Delta')],
#            names=['exp_name', None])

# %%
# 정렬 (주어진 Categorical 순서가 반영됨)
pivot_df = pivot_df.sort_index(level=['pe'], sort_remaining=False)

column_order = [
            (    'def',                        'Base'),
            (    'def',            '+ Feedback'),
            (    'def',            'Delta'),
            (    'vision',                  'Base'),
            (    'vision', '+ Feedback'),
            (    'vision', 'Delta'),
]

# 결과 확인
pivot_df = pivot_df[column_order]
pivot_df
# Out:
# exp_name       def                         vision
#               Base + Feedback     Delta      Base + Feedback     Delta
# pe
# cot       0.033333   0.155556  0.122222  0.142222   0.198889  0.056667

# %%
# change ('hr', 'Delta') column values to string with lambda
# pivot_df[('hr', 'Delta')] = pivot_df[('hr', 'Delta')].apply(lambda x: f'{x:.3f}')
pivot_df[('def', 'Delta')] = pivot_df[('def', 'Delta')].apply(
    lambda x: f'+{x:.3f}' if x > 0 else f'{x:.3f}'
)
pivot_df[('vision', 'Delta')] = pivot_df[('vision', 'Delta')].apply(
    lambda x: f'+{x:.3f}' if x > 0 else f'{x:.3f}'
)
pivot_df
# Out:
# exp_name       def                       vision
#               Base + Feedback   Delta      Base + Feedback   Delta
# pe
# cot       0.033333   0.155556  +0.122  0.142222   0.198889  +0.057

# %%
def insert_str(src_str, idx, insert_str):
    # LaTeX 문자열을 줄 단위로 나눔
    lines = src_str.splitlines()
    
    # 지정된 줄 번호 뒤에 \midrule 삽입
    lines.insert(idx, insert_str)
    
    # 다시 LaTeX 문자열로 결합
    return "\n".join(lines)

# %%
from IPython.display import display, Latex


tex_str = pivot_df.to_latex(buf=None, escape=True, bold_rows=False, position='!h', float_format="%.3f", multicolumn_format='c',
                            caption='Ablation study results for framework architecture, comparing accuracy across prompt engineering methods and scenarios.', label='tab:feedback_input')

tex_str = tex_str.replace('target_character', 'Scenario')
tex_str = tex_str.replace('pe &', 'PE &')
tex_str = tex_str.replace('exp_name &', '\\textbf{Feedback Input} &')
tex_str = tex_str.replace('gpt_model', '')
# tex_str = tex_str.replace('table', 'table*')
# tex_str = tex_str.replace('Self-Alignment', 'SA')
# tex_str = tex_str.replace('Self-Alignment', 'SA')
# tex_str = tex_str.replace('Feedback', 'FB')
tex_str = tex_str.replace('\cline{1-10}\n', '')
tex_str = tex_str.replace('+ Feedback', '+FB')
tex_str = tex_str.replace('cot', 'CoT').replace('tot', 'ToT').replace('got', 'GoT')
tex_str = tex_str.replace('mean & mean', '\\multicolumn{2}{c|}{\\textbf{Mean}}')
tex_str = tex_str.replace('\multicolumn{3}{c}{def}', '\multicolumn{3}{c|}{\\textbf{Text}}')
tex_str = tex_str.replace('\multicolumn{3}{c}{vision}', '\multicolumn{3}{c}{\\textbf{Image}}')
tex_str = tex_str.replace('Delta', '$\\Delta{}$')
tex_str = tex_str.replace('mean &', '\\textbf{Mean} &')

original_header = ' &  & Base & + SA & + FB & + FB \\& SA & Base & + SA & + FB & + FB \\& SA \\\\'
modified_header = original_header.replace(
    'Base', '\\textbf{Base}'
).replace(
    '+ SA', '\\textbf{+SA}'
).replace(
    '+ FB \\& SA', '\\textbf{+FB, SA}'
).replace(
    '+ FB', '\\textbf{+FB}'
)

# 기존 문자열에서 헤더 교체
tex_str = tex_str.replace(original_header, modified_header)

tex_str = tex_str.replace('\\begin{tabular}{llrrrrrrrr}', '\\begin{tabular}{ll|rrrr|rrrr}')

tex_str = tex_str.replace('chatgpt-4o', '\\texttt{chatgpt-4o-latest} (Dec 2024)')


tabular_header = "\\begin{tabular}{p{1.5cm}|p{0.73cm}p{0.73cm}p{0.73cm}|p{0.73cm}p{0.73cm}p{0.73cm}}"
# 기존 header를 새 header로 교체
tex_str = tex_str.replace("\\begin{tabular}{lrrlrrl}", tabular_header)

with open('feedback_input.tex', 'w') as f:
    f.write(tex_str)
display(Latex(tex_str))
# Out:
# \begin{table}[!h]
# \caption{Ablation study results for framework architecture, comparing accuracy across prompt engineering methods and scenarios.}
# \label{tab:feedback_input}
# \begin{tabular}{p{1.5cm}|p{0.73cm}p{0.73cm}p{0.73cm}|p{0.73cm}p{0.73cm}p{0.73cm}}
# \toprule
# \textbf{Feedback Input} & \multicolumn{3}{c|}{\textbf{Text}} & \multicolumn{3}{c}{\textbf{Image}} \\
#  & Base & +FB & $\Delta{}$ & Base & +FB & $\Delta{}$ \\
# PE &  &  &  &  &  &  \\
# \midrule
# CoT & 0.033 & 0.156 & +0.122 & 0.142 & 0.199 & +0.057 \\
# \bottomrule
# \end{tabular}
# \end{table}

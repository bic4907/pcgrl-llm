# %%
import wandb
import pandas as pd
import os
from tqdm import tqdm

from table_plotter import print_result_table

# %%
api = wandb.Api(timeout=600)

# %%
# get all runs for a project
runs = api.runs("inchangbaek4907/pcgrl-llm")
len(runs)
# Out:
# 140

# %%
# Specify cache directory
cache_dir = "./wandb_cache"
os.makedirs(cache_dir, exist_ok=True)

dfs = []
skipped_runs = []  # List to store IDs of skipped runs

for run in tqdm(runs):
    # Skip the run if it's not finished
    if run.state != "finished":
        print(f"Skipping run {run.id} (state: {run.state})")
        skipped_runs.append(run.id)
        continue

    # Define cache filename based on run ID
    cache_file = os.path.join(cache_dir, f"{run.id}.csv")
    
    # Check if cached file exists
    if os.path.exists(cache_file):
        # Load cached DataFrame
        df = pd.read_csv(cache_file)
    else:
        # Retrieve history data for Evaluation/similarity and diversity
        sim = run.history(keys=["Evaluation/similarity", "Evaluation/llm_iteration"])
        div = run.history(keys=["Evaluation/diversity", "Evaluation/llm_iteration"])
        llm_sim = run.history(keys=["Evaluation/llm/similarity", "Evaluation/llm_iteration"])
        llm_div = run.history(keys=["Evaluation/llm/diversity", "Evaluation/llm_iteration"])
        
        # Sequentially merge the DataFrames on "Evaluation/llm_iteration"
        df = pd.merge(sim, div, on="Evaluation/llm_iteration", how="outer")
        df = df.drop(columns=["_step_x", "_step_y"], errors="ignore")
        if 'Evaluation/llm_iteration' in llm_sim.columns:
            df = pd.merge(df, llm_sim, on="Evaluation/llm_iteration", how="outer")
            df = df.drop(columns=["_step_x", "_step_y"], errors="ignore")
        if 'Evaluation/llm_iteration' in llm_div.columns:
            df = pd.merge(df, llm_div, on="Evaluation/llm_iteration", how="outer")
            df = df.drop(columns=["_step_x", "_step_y"], errors="ignore")
            
        # Now, 'df' contains all the merged data based on "Evaluation/llm_iteration"

        df = df.drop(columns=["_step_x", "_step_y"], errors="ignore")

        # Add run config to DataFrame with prefix 'config.'
        for key, value in run.config.items():
            if isinstance(value, list):
                value = ",".join(map(str, value))  # Convert list to comma-separated string
            df[key] = value

        # Filter columns
        key_filter = ['target_character', 'pe', 'branch_factor', 'exp_name', 'evaluator', 'total_iterations', 
                      'reward_feature', 'fewshot', 'problem', 'seed', 'Evaluation/llm_iteration', 
                      'Evaluation/similarity', 'Evaluation/diversity']
        auxiliary_key_filter = ['Evaluation/llm/similarity', 'Evaluation/llm/diversity']
        
        try:
            df = df[key_filter + auxiliary_key_filter]
        except KeyError:
            df = df[key_filter]
        
        # Save DataFrame to cache as CSV
        df.to_csv(cache_file, index=False)
    
    # Append DataFrame to list
    dfs.append(df)

# Concatenate all DataFrames
df = pd.concat(dfs, ignore_index=True)
df.head()  # Display the first few rows for inspection

# Print summary of skipped runs
print("\nSummary of Skipped Runs:")
print(f"Total skipped runs: {len(skipped_runs)}")
print("Skipped run IDs:", skipped_runs)
# Out:
# 100%|██████████| 140/140 [00:00<00:00, 168.94it/s]
# Summary of Skipped Runs:
# Total skipped runs: 0
# Skipped run IDs: []

# %%
time_str = pd.Timestamp.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
df.to_csv(f"wandb_output_{time_str}.csv", index=False)

# %% [raw]
# # load the csv
# df = pd.read_csv("wandb_output_2024-11-06-09-47-45.csv")

# %%
df['seed'] = df['seed'] % 3
df
# Out:
#     target_character   pe  branch_factor exp_name evaluator  total_iterations  \
# 0                  N   io              2      def       vit                 1
# 1                  M   io              2      def       vit                 1
# 2                  F   io              2      def       vit                 1
# 3                  D   io              2      def       vit                 1
# 4                  C   io              2      def       vit                 1
# ..               ...  ...            ...      ...       ...               ...
# 755                C  tot              2      def       vit                 6
# 756                C  tot              2      def       vit                 6
# 757                C  tot              2      def       vit                 6
# 758                C  tot              2      def       vit                 6
# 759                C  tot              2      def       vit                 6
#
#     reward_feature  fewshot problem  seed  Evaluation/llm_iteration  \
# 0            array    False  binary     1                         1
# 1            array    False  binary     1                         1
# 2            array    False  binary     1                         1
# 3            array    False  binary     1                         1
# 4            array    False  binary     1                         1
# ..             ...      ...     ...   ...                       ...
# 755          array     True  binary     0                         2
# 756          array     True  binary     0                         3
# 757          array     True  binary     0                         4
# 758          array     True  binary     0                         5
# 759          array     True  binary     0                         6
#
#      Evaluation/similarity  Evaluation/diversity  Evaluation/llm/similarity  \
# 0                 0.018449              0.595029                        NaN
# 1                 0.045062              0.147950                        NaN
# 2                 0.799518              0.000000                        NaN
# 3                 0.032404              0.137656                        NaN
# 4                 0.765589              0.000347                        NaN
# ..                     ...                   ...                        ...
# 755               0.044665              0.000000                        NaN
# 756               0.193625              0.153446                        NaN
# 757               0.210502              0.075594                        NaN
# 758               0.031002              0.000000                        NaN
# 759               0.155776              0.000000                        NaN
#
#      Evaluation/llm/diversity
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 755                       NaN
# 756                       NaN
# 757                       NaN
# 758                       NaN
# 759                       NaN
#
# [760 rows x 15 columns]

# %%
# remove pe == cotsc
df = df[df['pe'] != 'cotsc']

# if the exname is not def make the pe to 'pe+exp_name'
df['pe'] = df.apply(lambda x: x['pe'] + '-' +  x['exp_name'] if x['exp_name'] != 'def' else x['pe'], axis=1)
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_8097/1595903143.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pe'] = df.apply(lambda x: x['pe'] + '-' +  x['exp_name'] if x['exp_name'] != 'def' else x['pe'], axis=1)

# %%
df.groupby(['pe', 'evaluator', 'fewshot', 'seed']).count()
# Out:
#                             target_character  branch_factor  exp_name  \
# pe  evaluator fewshot seed
# cot vit       False   0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
#               True    0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
# got llm       False   0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
#     vit       False   0                   30             30        30
#                       1                   30             30        30
#                       2                   25             25        25
#               True    0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
# io  vit       False   0                    5              5         5
#                       1                    5              5         5
#                       2                    5              5         5
# tot llm       False   0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
#     vit       False   0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
#               True    0                   30             30        30
#                       1                   30             30        30
#                       2                   30             30        30
#
#                             total_iterations  reward_feature  problem  \
# pe  evaluator fewshot seed
# cot vit       False   0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
#               True    0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
# got llm       False   0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
#     vit       False   0                   30              30       30
#                       1                   30              30       30
#                       2                   25              25       25
#               True    0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
# io  vit       False   0                    5               5        5
#                       1                    5               5        5
#                       2                    5               5        5
# tot llm       False   0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
#     vit       False   0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
#               True    0                   30              30       30
#                       1                   30              30       30
#                       2                   30              30       30
#
#                             Evaluation/llm_iteration  Evaluation/similarity  \
# pe  evaluator fewshot seed
# cot vit       False   0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
#               True    0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
# got llm       False   0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
#     vit       False   0                           30                     30
#                       1                           30                     30
#                       2                           25                     25
#               True    0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
# io  vit       False   0                            5                      5
#                       1                            5                      5
#                       2                            5                      5
# tot llm       False   0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
#     vit       False   0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
#               True    0                           30                     30
#                       1                           30                     30
#                       2                           30                     30
#
#                             Evaluation/diversity  Evaluation/llm/similarity  \
# pe  evaluator fewshot seed
# cot vit       False   0                       30                          0
#                       1                       30                          0
#                       2                       30                          0
#               True    0                       30                          0
#                       1                       30                          0
#                       2                       30                          0
# got llm       False   0                       30                         30
#                       1                       30                         30
#                       2                       30                         30
#     vit       False   0                       30                          0
#                       1                       30                          0
#                       2                       25                          0
#               True    0                       30                          0
#                       1                       30                          0
#                       2                       30                          0
# io  vit       False   0                        5                          0
#                       1                        5                          0
#                       2                        5                          0
# tot llm       False   0                       30                         30
#                       1                       30                         30
#                       2                       30                         30
#     vit       False   0                       30                          0
#                       1                       30                          0
#                       2                       30                          0
#               True    0                       30                          0
#                       1                       30                          0
#                       2                       30                          0
#
#                             Evaluation/llm/diversity
# pe  evaluator fewshot seed
# cot vit       False   0                            0
#                       1                            0
#                       2                            0
#               True    0                            0
#                       1                            0
#                       2                            0
# got llm       False   0                           30
#                       1                           30
#                       2                           30
#     vit       False   0                            0
#                       1                            0
#                       2                            0
#               True    0                            0
#                       1                            0
#                       2                            0
# io  vit       False   0                            0
#                       1                            0
#                       2                            0
# tot llm       False   0                           30
#                       1                           30
#                       2                           30
#     vit       False   0                            0
#                       1                            0
#                       2                            0
#               True    0                            0
#                       1                            0
#                       2                            0

# %%
# Min-max Normalize Evaluation/similarity and Evaluation/diversity for each 'target_character' and add a new column 'Evaluation/similarity/norm' and 'Evaluation/diversity/norm'
df['Evaluation/similarity/norm'] = df.groupby('target_character')['Evaluation/similarity'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
df['Evaluation/diversity/norm'] = df.groupby('target_character')['Evaluation/diversity'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
df
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_8097/254095163.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Evaluation/similarity/norm'] = df.groupby('target_character')['Evaluation/similarity'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_8097/254095163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Evaluation/diversity/norm'] = df.groupby('target_character')['Evaluation/diversity'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
#     target_character   pe  branch_factor exp_name evaluator  total_iterations  \
# 0                  N   io              2      def       vit                 1
# 1                  M   io              2      def       vit                 1
# 2                  F   io              2      def       vit                 1
# 3                  D   io              2      def       vit                 1
# 4                  C   io              2      def       vit                 1
# ..               ...  ...            ...      ...       ...               ...
# 755                C  tot              2      def       vit                 6
# 756                C  tot              2      def       vit                 6
# 757                C  tot              2      def       vit                 6
# 758                C  tot              2      def       vit                 6
# 759                C  tot              2      def       vit                 6
#
#     reward_feature  fewshot problem  seed  Evaluation/llm_iteration  \
# 0            array    False  binary     1                         1
# 1            array    False  binary     1                         1
# 2            array    False  binary     1                         1
# 3            array    False  binary     1                         1
# 4            array    False  binary     1                         1
# ..             ...      ...     ...   ...                       ...
# 755          array     True  binary     0                         2
# 756          array     True  binary     0                         3
# 757          array     True  binary     0                         4
# 758          array     True  binary     0                         5
# 759          array     True  binary     0                         6
#
#      Evaluation/similarity  Evaluation/diversity  Evaluation/llm/similarity  \
# 0                 0.018449              0.595029                        NaN
# 1                 0.045062              0.147950                        NaN
# 2                 0.799518              0.000000                        NaN
# 3                 0.032404              0.137656                        NaN
# 4                 0.765589              0.000347                        NaN
# ..                     ...                   ...                        ...
# 755               0.044665              0.000000                        NaN
# 756               0.193625              0.153446                        NaN
# 757               0.210502              0.075594                        NaN
# 758               0.031002              0.000000                        NaN
# 759               0.155776              0.000000                        NaN
#
#      Evaluation/llm/diversity  Evaluation/similarity/norm  \
# 0                         NaN                    0.009704
# 1                         NaN                    0.044978
# 2                         NaN                    0.950696
# 3                         NaN                    0.031829
# 4                         NaN                    0.947774
# ..                        ...                         ...
# 755                       NaN                    0.044342
# 756                       NaN                    0.231013
# 757                       NaN                    0.252163
# 758                       NaN                    0.027221
# 759                       NaN                    0.183582
#
#      Evaluation/diversity/norm
# 0                     1.000000
# 1                     0.338434
# 2                     0.000000
# 3                     0.265148
# 4                     0.000649
# ..                         ...
# 755                   0.000000
# 756                   0.286957
# 757                   0.141367
# 758                   0.000000
# 759                   0.000000
#
# [730 rows x 17 columns]

# %%
# 각 실험마다 마지막 Iteration의 Similarity와 Diversity를 가져옴, 또한 각 실험의 최대 Similarity와 최소 Diversity를 가져옴
# Update the function to include calculations based on normalized similarity and diversity
experiment_cols = ['pe', 'evaluator', 'fewshot', 'seed']  # Assuming these are the experiment identifiers as per user's requirement
experiment_cols_without_seed = ['pe', 'evaluator', 'fewshot']

# %%
def extract_metrics_with_norm(group):
    # Maximum similarity iteration row
    max_sim_row = group.loc[group['Evaluation/similarity'].idxmax()]
    max_sim_norm_row = group.loc[group['Evaluation/similarity/norm'].idxmax()]
    # Final iteration row
    final_iteration_row = group.loc[group['Evaluation/llm_iteration'].idxmax()]
    
    return pd.Series({
        'Max Similarity Iteration': max_sim_row['Evaluation/llm_iteration'],
        'Max Similarity': max_sim_row['Evaluation/similarity'],
        'Diversity at Max Similarity': max_sim_row['Evaluation/diversity'],
        
        'Max Normalized Similarity Iteration': max_sim_norm_row['Evaluation/llm_iteration'],
        'Max Normalized Similarity': max_sim_norm_row['Evaluation/similarity/norm'],
        'Diversity at Max Normalized Similarity': max_sim_norm_row['Evaluation/diversity/norm'],
        
        'Final Iteration': final_iteration_row['Evaluation/llm_iteration'],
        'Final Similarity': final_iteration_row['Evaluation/similarity'],
        'Final Diversity': final_iteration_row['Evaluation/diversity'],
        'Final Normalized Similarity': final_iteration_row['Evaluation/similarity/norm'],
        'Final Normalized Diversity': final_iteration_row['Evaluation/diversity/norm']
    })

# Apply the updated function to each experiment group
result = df.groupby(experiment_cols).apply(extract_metrics_with_norm).reset_index()

# Display the enhanced results to the user
result
# Out:
# /var/folders/x_/2lt9k5kn52q43m1_z0kp7tfm0000gn/T/ipykernel_8097/2537490999.py:25: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = df.groupby(experiment_cols).apply(extract_metrics_with_norm).reset_index()
#      pe evaluator  fewshot  seed  Max Similarity Iteration  Max Similarity  \
# 0   cot       vit    False     0                       3.0        0.804452
# 1   cot       vit    False     1                       3.0        0.811480
# 2   cot       vit    False     2                       2.0        0.820263
# 3   cot       vit     True     0                       6.0        0.796896
# 4   cot       vit     True     1                       1.0        0.753034
# 5   cot       vit     True     2                       2.0        0.736431
# 6   got       llm    False     0                       3.0        0.808905
# 7   got       llm    False     1                       1.0        0.814916
# 8   got       llm    False     2                       1.0        0.705457
# 9   got       vit    False     0                       2.0        0.840231
# 10  got       vit    False     1                       5.0        0.749879
# 11  got       vit    False     2                       1.0        0.730140
# 12  got       vit     True     0                       5.0        0.742743
# 13  got       vit     True     1                       1.0        0.821257
# 14  got       vit     True     2                       1.0        0.736431
# 15   io       vit    False     0                       1.0        0.393252
# 16   io       vit    False     1                       1.0        0.799518
# 17   io       vit    False     2                       1.0        0.047852
# 18  tot       llm    False     0                       1.0        0.571914
# 19  tot       llm    False     1                       3.0        0.787611
# 20  tot       llm    False     2                       2.0        0.811480
# 21  tot       vit    False     0                       5.0        0.811480
# 22  tot       vit    False     1                       6.0        0.795768
# 23  tot       vit    False     2                       1.0        0.792379
# 24  tot       vit     True     0                       1.0        0.736431
# 25  tot       vit     True     1                       1.0        0.752456
# 26  tot       vit     True     2                       1.0        0.795447
#
#     Diversity at Max Similarity  Max Normalized Similarity Iteration  \
# 0                      0.000218                                  3.0
# 1                      0.000000                                  3.0
# 2                      0.000110                                  2.0
# 3                      0.000059                                  6.0
# 4                      0.001600                                  1.0
# 5                      0.000000                                  2.0
# 6                      0.000050                                  3.0
# 7                      0.000028                                  5.0
# 8                      0.013302                                  5.0
# 9                      0.000000                                  2.0
# 10                     0.000000                                  5.0
# 11                     0.003303                                  1.0
# 12                     0.000128                                  5.0
# 13                     0.000215                                  2.0
# 14                     0.000000                                  2.0
# 15                     0.099056                                  1.0
# 16                     0.000000                                  1.0
# 17                     0.001505                                  1.0
# 18                     0.125603                                  1.0
# 19                     0.000012                                  3.0
# 20                     0.000000                                  2.0
# 21                     0.000000                                  5.0
# 22                     0.000032                                  6.0
# 23                     0.000000                                  1.0
# 24                     0.000000                                  1.0
# 25                     0.000210                                  1.0
# 26                     0.000000                                  1.0
#
#     Max Normalized Similarity  Diversity at Max Normalized Similarity  \
# 0                    0.956670                            5.519364e-04
# 1                    0.999873                            0.000000e+00
# 2                    0.975819                            2.771142e-04
# 3                    0.981664                            9.890662e-05
# 4                    0.894402                            4.045460e-03
# 5                    0.874295                            0.000000e+00
# 6                    0.962063                            1.251945e-04
# 7                    0.999873                            0.000000e+00
# 8                    0.874275                            1.421834e-03
# 9                    1.000000                            0.000000e+00
# 10                   0.945856                            0.000000e+00
# 11                   0.866677                            8.352004e-03
# 12                   0.881940                            3.247471e-04
# 13                   1.000000                            6.411457e-07
# 14                   0.918990                            1.042629e-02
# 15                   0.488123                            2.265887e-01
# 16                   0.950696                            0.000000e+00
# 17                   0.046417                            2.529274e-03
# 18                   0.675059                            3.176462e-01
# 19                   0.975371                            2.205384e-05
# 20                   0.999873                            0.000000e+00
# 21                   0.999873                            0.000000e+00
# 22                   0.980255                            5.301910e-05
# 23                   1.000000                            0.000000e+00
# 24                   0.874295                            0.000000e+00
# 25                   0.893702                            5.316309e-04
# 26                   1.000000                            0.000000e+00
#
#     Final Iteration  Final Similarity  Final Diversity  \
# 0               6.0          0.029134         0.218648
# 1               6.0          0.807933         0.000003
# 2               6.0          0.031065         0.234873
# 3               6.0          0.796896         0.000059
# 4               6.0          0.018554         0.362184
# 5               6.0          0.025740         0.160454
# 6               6.0          0.031173         0.000000
# 7               6.0          0.035396         0.017532
# 8               6.0          0.018690         0.198087
# 9               6.0          0.103562         0.000323
# 10              6.0          0.035828         0.029768
# 11              6.0          0.352290         0.208113
# 12              6.0          0.010677         0.005324
# 13              6.0          0.063482         0.176587
# 14              6.0          0.581198         0.015111
# 15              1.0          0.393252         0.099056
# 16              1.0          0.018449         0.595029
# 17              1.0          0.047852         0.001505
# 18              6.0          0.038524         0.085488
# 19              6.0          0.310928         0.000000
# 20              6.0          0.736431         0.000000
# 21              6.0          0.116937         0.373515
# 22              6.0          0.019727         0.255491
# 23              6.0          0.736431         0.000000
# 24              6.0          0.082441         0.170372
# 25              6.0          0.016628         0.194118
# 26              6.0          0.015223         0.241005
#
#     Final Normalized Similarity  Final Normalized Diversity
# 0                      0.024706                    0.500154
# 1                      0.995445                    0.000005
# 2                      0.027164                    0.537270
# 3                      0.981664                    0.000099
# 4                      0.009836                    0.608684
# 5                      0.018807                    0.269657
# 6                      0.027300                    0.000000
# 7                      0.032728                    0.032786
# 8                      0.005088                    0.500958
# 9                      0.122481                    0.000621
# 10                     0.033269                    0.055669
# 11                     0.409089                    0.526312
# 12                     0.000000                    0.008947
# 13                     0.065932                    0.296770
# 14                     0.712346                    0.025395
# 15                     0.488123                    0.226589
# 16                     0.009704                    1.000000
# 17                     0.046417                    0.002529
# 18                     0.036656                    0.195554
# 19                     0.358998                    0.000000
# 20                     0.874295                    0.000000
# 21                     0.136453                    0.854412
# 22                     0.012734                    0.584434
# 23                     0.874295                    0.000000
# 24                     0.092550                    0.389723
# 25                     0.011731                    0.373902
# 26                     0.000890                    0.609496

# %%
plotter = {'Max Normalized Similarity': ['mean', 'std'], 'Diversity at Max Normalized Similarity': ['mean', 'std'], 'Max Similarity Iteration': ['mean', 'std'], 'Final Normalized Similarity': ['mean', 'std'], 'Final Normalized Diversity': ['mean', 'std']}

# %%
result.groupby(['pe', 'evaluator', 'fewshot']).agg(plotter)
# Out:
#                       Max Normalized Similarity            \
#                                            mean       std
# pe  evaluator fewshot
# cot vit       False                    0.977454  0.021648
#               True                     0.916787  0.057077
# got llm       False                    0.945404  0.064435
#     vit       False                    0.937511  0.067052
#               True                     0.933643  0.060379
# io  vit       False                    0.495079  0.452180
# tot llm       False                    0.883435  0.180874
#     vit       False                    0.993376  0.011363
#               True                     0.922666  0.067673
#
#                       Diversity at Max Normalized Similarity            \
#                                                         mean       std
# pe  evaluator fewshot
# cot vit       False                                 0.000276  0.000276
#               True                                  0.001381  0.002308
# got llm       False                                 0.000516  0.000787
#     vit       False                                 0.002784  0.004822
#               True                                  0.003584  0.005928
# io  vit       False                                 0.076373  0.130097
# tot llm       False                                 0.105889  0.183387
#     vit       False                                 0.000018  0.000031
#               True                                  0.000177  0.000307
#
#                       Max Similarity Iteration            \
#                                           mean       std
# pe  evaluator fewshot
# cot vit       False                   2.666667  0.577350
#               True                    3.000000  2.645751
# got llm       False                   1.666667  1.154701
#     vit       False                   2.666667  2.081666
#               True                    2.333333  2.309401
# io  vit       False                   1.000000  0.000000
# tot llm       False                   2.000000  1.000000
#     vit       False                   4.000000  2.645751
#               True                    1.000000  0.000000
#
#                       Final Normalized Similarity            \
#                                              mean       std
# pe  evaluator fewshot
# cot vit       False                      0.349105  0.559748
#               True                       0.336769  0.558513
# got llm       False                      0.021705  0.014645
#     vit       False                      0.188280  0.196360
#               True                       0.259426  0.393623
# io  vit       False                      0.181415  0.266251
# tot llm       False                      0.423316  0.422508
#     vit       False                      0.341161  0.465834
#               True                       0.035057  0.050085
#
#                       Final Normalized Diversity
#                                             mean       std
# pe  evaluator fewshot
# cot vit       False                     0.345809  0.300050
#               True                      0.292813  0.304952
# got llm       False                     0.177915  0.280243
#     vit       False                     0.194201  0.288931
#               True                      0.110371  0.161636
# io  vit       False                     0.409706  0.523341
# tot llm       False                     0.065185  0.112903
#     vit       False                     0.479615  0.436744
#               True                      0.457707  0.131691

# %% [markdown]
# ## Exp 1. Reasoning performance of prompt engineering

# %%
# Get the fewshot=False and evaluator=vit
exp1_df = result[(result['fewshot'] == False) & (result['evaluator'] == 'vit')]
exp1_df.groupby(experiment_cols_without_seed).count()
# Out:
#                        seed  Max Similarity Iteration  Max Similarity  \
# pe  evaluator fewshot
# cot vit       False       3                         3               3
# got vit       False       3                         3               3
# io  vit       False       3                         3               3
# tot vit       False       3                         3               3
#
#                        Diversity at Max Similarity  \
# pe  evaluator fewshot
# cot vit       False                              3
# got vit       False                              3
# io  vit       False                              3
# tot vit       False                              3
#
#                        Max Normalized Similarity Iteration  \
# pe  evaluator fewshot
# cot vit       False                                      3
# got vit       False                                      3
# io  vit       False                                      3
# tot vit       False                                      3
#
#                        Max Normalized Similarity  \
# pe  evaluator fewshot
# cot vit       False                            3
# got vit       False                            3
# io  vit       False                            3
# tot vit       False                            3
#
#                        Diversity at Max Normalized Similarity  \
# pe  evaluator fewshot
# cot vit       False                                         3
# got vit       False                                         3
# io  vit       False                                         3
# tot vit       False                                         3
#
#                        Final Iteration  Final Similarity  Final Diversity  \
# pe  evaluator fewshot
# cot vit       False                  3                 3                3
# got vit       False                  3                 3                3
# io  vit       False                  3                 3                3
# tot vit       False                  3                 3                3
#
#                        Final Normalized Similarity  Final Normalized Diversity
# pe  evaluator fewshot
# cot vit       False                              3                           3
# got vit       False                              3                           3
# io  vit       False                              3                           3
# tot vit       False                              3                           3

# %%
exp1_df.groupby(experiment_cols_without_seed).agg(plotter)
# Out:
#                       Max Normalized Similarity            \
#                                            mean       std
# pe  evaluator fewshot
# cot vit       False                    0.977454  0.021648
# got vit       False                    0.937511  0.067052
# io  vit       False                    0.495079  0.452180
# tot vit       False                    0.993376  0.011363
#
#                       Diversity at Max Normalized Similarity            \
#                                                         mean       std
# pe  evaluator fewshot
# cot vit       False                                 0.000276  0.000276
# got vit       False                                 0.002784  0.004822
# io  vit       False                                 0.076373  0.130097
# tot vit       False                                 0.000018  0.000031
#
#                       Max Similarity Iteration            \
#                                           mean       std
# pe  evaluator fewshot
# cot vit       False                   2.666667  0.577350
# got vit       False                   2.666667  2.081666
# io  vit       False                   1.000000  0.000000
# tot vit       False                   4.000000  2.645751
#
#                       Final Normalized Similarity            \
#                                              mean       std
# pe  evaluator fewshot
# cot vit       False                      0.349105  0.559748
# got vit       False                      0.188280  0.196360
# io  vit       False                      0.181415  0.266251
# tot vit       False                      0.341161  0.465834
#
#                       Final Normalized Diversity
#                                             mean       std
# pe  evaluator fewshot
# cot vit       False                     0.345809  0.300050
# got vit       False                     0.194201  0.288931
# io  vit       False                     0.409706  0.523341
# tot vit       False                     0.479615  0.436744

# %%
print_result_table(exp1_df, category_columns=['pe'])
# Out:
# <style type="text/css">
# #T_e6d21 caption {
#   font-size: 16px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_e6d21 th {
#   text-align: center;
# }
# #T_e6d21 td {
#   text-align: center;
# }
# #T_e6d21_row0_col0, #T_e6d21_row0_col1, #T_e6d21_row0_col2, #T_e6d21_row0_col3, #T_e6d21_row0_col4, #T_e6d21_row1_col0, #T_e6d21_row1_col1, #T_e6d21_row1_col2, #T_e6d21_row1_col3, #T_e6d21_row1_col4, #T_e6d21_row2_col0, #T_e6d21_row2_col1, #T_e6d21_row2_col2, #T_e6d21_row2_col3, #T_e6d21_row2_col4, #T_e6d21_row3_col0, #T_e6d21_row3_col1, #T_e6d21_row3_col2, #T_e6d21_row3_col3, #T_e6d21_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
# }
# </style>
# <table id="T_e6d21">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Iteration Type</th>
#       <th id="T_e6d21_level0_col0" class="col_heading level0 col0" colspan="3">Best Similarity Iteration (Mean ± Std)</th>
#       <th id="T_e6d21_level0_col3" class="col_heading level0 col3" colspan="2">Final Iteration (Mean ± Std)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_e6d21_level1_col0" class="col_heading level1 col0" >Iteration</th>
#       <th id="T_e6d21_level1_col1" class="col_heading level1 col1" >Similarity</th>
#       <th id="T_e6d21_level1_col2" class="col_heading level1 col2" >Diversity</th>
#       <th id="T_e6d21_level1_col3" class="col_heading level1 col3" >Similarity</th>
#       <th id="T_e6d21_level1_col4" class="col_heading level1 col4" >Diversity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pe</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6d21_level0_row0" class="row_heading level0 row0" >io</th>
#       <td id="T_e6d21_row0_col0" class="data row0 col0" >1.000 ± 0.000</td>
#       <td id="T_e6d21_row0_col1" class="data row0 col1" >0.495 ± 0.452</td>
#       <td id="T_e6d21_row0_col2" class="data row0 col2" >0.076 ± 0.130</td>
#       <td id="T_e6d21_row0_col3" class="data row0 col3" >0.181 ± 0.266</td>
#       <td id="T_e6d21_row0_col4" class="data row0 col4" >0.410 ± 0.523</td>
#     </tr>
#     <tr>
#       <th id="T_e6d21_level0_row1" class="row_heading level0 row1" >cot</th>
#       <td id="T_e6d21_row1_col0" class="data row1 col0" >2.667 ± 0.577</td>
#       <td id="T_e6d21_row1_col1" class="data row1 col1" >0.977 ± 0.022</td>
#       <td id="T_e6d21_row1_col2" class="data row1 col2" >0.000 ± 0.000</td>
#       <td id="T_e6d21_row1_col3" class="data row1 col3" >0.349 ± 0.560</td>
#       <td id="T_e6d21_row1_col4" class="data row1 col4" >0.346 ± 0.300</td>
#     </tr>
#     <tr>
#       <th id="T_e6d21_level0_row2" class="row_heading level0 row2" >tot</th>
#       <td id="T_e6d21_row2_col0" class="data row2 col0" >4.000 ± 2.646</td>
#       <td id="T_e6d21_row2_col1" class="data row2 col1" >0.993 ± 0.011</td>
#       <td id="T_e6d21_row2_col2" class="data row2 col2" >0.000 ± 0.000</td>
#       <td id="T_e6d21_row2_col3" class="data row2 col3" >0.341 ± 0.466</td>
#       <td id="T_e6d21_row2_col4" class="data row2 col4" >0.480 ± 0.437</td>
#     </tr>
#     <tr>
#       <th id="T_e6d21_level0_row3" class="row_heading level0 row3" >got</th>
#       <td id="T_e6d21_row3_col0" class="data row3 col0" >2.667 ± 2.082</td>
#       <td id="T_e6d21_row3_col1" class="data row3 col1" >0.938 ± 0.067</td>
#       <td id="T_e6d21_row3_col2" class="data row3 col2" >0.003 ± 0.005</td>
#       <td id="T_e6d21_row3_col3" class="data row3 col3" >0.188 ± 0.196</td>
#       <td id="T_e6d21_row3_col4" class="data row3 col4" >0.194 ± 0.289</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exp. 2: LLM and ViT-based node evaluation

# %%
exp2_df = result[(result['fewshot'] == False)]
exp2_df = exp2_df[exp2_df['pe'].isin(['tot', 'got'])]
exp2_df.groupby(experiment_cols_without_seed).count()
# Out:
#                        seed  Max Similarity Iteration  Max Similarity  \
# pe  evaluator fewshot
# got llm       False       3                         3               3
#     vit       False       3                         3               3
# tot llm       False       3                         3               3
#     vit       False       3                         3               3
#
#                        Diversity at Max Similarity  \
# pe  evaluator fewshot
# got llm       False                              3
#     vit       False                              3
# tot llm       False                              3
#     vit       False                              3
#
#                        Max Normalized Similarity Iteration  \
# pe  evaluator fewshot
# got llm       False                                      3
#     vit       False                                      3
# tot llm       False                                      3
#     vit       False                                      3
#
#                        Max Normalized Similarity  \
# pe  evaluator fewshot
# got llm       False                            3
#     vit       False                            3
# tot llm       False                            3
#     vit       False                            3
#
#                        Diversity at Max Normalized Similarity  \
# pe  evaluator fewshot
# got llm       False                                         3
#     vit       False                                         3
# tot llm       False                                         3
#     vit       False                                         3
#
#                        Final Iteration  Final Similarity  Final Diversity  \
# pe  evaluator fewshot
# got llm       False                  3                 3                3
#     vit       False                  3                 3                3
# tot llm       False                  3                 3                3
#     vit       False                  3                 3                3
#
#                        Final Normalized Similarity  Final Normalized Diversity
# pe  evaluator fewshot
# got llm       False                              3                           3
#     vit       False                              3                           3
# tot llm       False                              3                           3
#     vit       False                              3                           3

# %%
# get only cot and tot
exp2_df.groupby(experiment_cols_without_seed).agg(plotter)
# Out:
#                       Max Normalized Similarity            \
#                                            mean       std
# pe  evaluator fewshot
# got llm       False                    0.945404  0.064435
#     vit       False                    0.937511  0.067052
# tot llm       False                    0.883435  0.180874
#     vit       False                    0.993376  0.011363
#
#                       Diversity at Max Normalized Similarity            \
#                                                         mean       std
# pe  evaluator fewshot
# got llm       False                                 0.000516  0.000787
#     vit       False                                 0.002784  0.004822
# tot llm       False                                 0.105889  0.183387
#     vit       False                                 0.000018  0.000031
#
#                       Max Similarity Iteration            \
#                                           mean       std
# pe  evaluator fewshot
# got llm       False                   1.666667  1.154701
#     vit       False                   2.666667  2.081666
# tot llm       False                   2.000000  1.000000
#     vit       False                   4.000000  2.645751
#
#                       Final Normalized Similarity            \
#                                              mean       std
# pe  evaluator fewshot
# got llm       False                      0.021705  0.014645
#     vit       False                      0.188280  0.196360
# tot llm       False                      0.423316  0.422508
#     vit       False                      0.341161  0.465834
#
#                       Final Normalized Diversity
#                                             mean       std
# pe  evaluator fewshot
# got llm       False                     0.177915  0.280243
#     vit       False                     0.194201  0.288931
# tot llm       False                     0.065185  0.112903
#     vit       False                     0.479615  0.436744

# %%
print_result_table(exp2_df, category_columns=['evaluator', 'pe'])
# Out:
# <style type="text/css">
# #T_2739d caption {
#   font-size: 16px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_2739d th {
#   text-align: center;
# }
# #T_2739d td {
#   text-align: center;
# }
# #T_2739d_row0_col0, #T_2739d_row0_col1, #T_2739d_row0_col2, #T_2739d_row0_col3, #T_2739d_row0_col4, #T_2739d_row1_col0, #T_2739d_row1_col1, #T_2739d_row1_col2, #T_2739d_row1_col3, #T_2739d_row1_col4, #T_2739d_row2_col0, #T_2739d_row2_col1, #T_2739d_row2_col2, #T_2739d_row2_col3, #T_2739d_row2_col4, #T_2739d_row3_col0, #T_2739d_row3_col1, #T_2739d_row3_col2, #T_2739d_row3_col3, #T_2739d_row3_col4 {
#   text-align: center;
#   border: 1px solid black;
# }
# </style>
# <table id="T_2739d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Iteration Type</th>
#       <th id="T_2739d_level0_col0" class="col_heading level0 col0" colspan="3">Best Similarity Iteration (Mean ± Std)</th>
#       <th id="T_2739d_level0_col3" class="col_heading level0 col3" colspan="2">Final Iteration (Mean ± Std)</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_2739d_level1_col0" class="col_heading level1 col0" >Iteration</th>
#       <th id="T_2739d_level1_col1" class="col_heading level1 col1" >Similarity</th>
#       <th id="T_2739d_level1_col2" class="col_heading level1 col2" >Diversity</th>
#       <th id="T_2739d_level1_col3" class="col_heading level1 col3" >Similarity</th>
#       <th id="T_2739d_level1_col4" class="col_heading level1 col4" >Diversity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >evaluator</th>
#       <th class="index_name level1" >pe</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2739d_level0_row0" class="row_heading level0 row0" rowspan="2">llm</th>
#       <th id="T_2739d_level1_row0" class="row_heading level1 row0" >tot</th>
#       <td id="T_2739d_row0_col0" class="data row0 col0" >2.000 ± 1.000</td>
#       <td id="T_2739d_row0_col1" class="data row0 col1" >0.883 ± 0.181</td>
#       <td id="T_2739d_row0_col2" class="data row0 col2" >0.106 ± 0.183</td>
#       <td id="T_2739d_row0_col3" class="data row0 col3" >0.423 ± 0.423</td>
#       <td id="T_2739d_row0_col4" class="data row0 col4" >0.065 ± 0.113</td>
#     </tr>
#     <tr>
#       <th id="T_2739d_level1_row1" class="row_heading level1 row1" >got</th>
#       <td id="T_2739d_row1_col0" class="data row1 col0" >1.667 ± 1.155</td>
#       <td id="T_2739d_row1_col1" class="data row1 col1" >0.945 ± 0.064</td>
#       <td id="T_2739d_row1_col2" class="data row1 col2" >0.001 ± 0.001</td>
#       <td id="T_2739d_row1_col3" class="data row1 col3" >0.022 ± 0.015</td>
#       <td id="T_2739d_row1_col4" class="data row1 col4" >0.178 ± 0.280</td>
#     </tr>
#     <tr>
#       <th id="T_2739d_level0_row2" class="row_heading level0 row2" rowspan="2">vit</th>
#       <th id="T_2739d_level1_row2" class="row_heading level1 row2" >tot</th>
#       <td id="T_2739d_row2_col0" class="data row2 col0" >4.000 ± 2.646</td>
#       <td id="T_2739d_row2_col1" class="data row2 col1" >0.993 ± 0.011</td>
#       <td id="T_2739d_row2_col2" class="data row2 col2" >0.000 ± 0.000</td>
#       <td id="T_2739d_row2_col3" class="data row2 col3" >0.341 ± 0.466</td>
#       <td id="T_2739d_row2_col4" class="data row2 col4" >0.480 ± 0.437</td>
#     </tr>
#     <tr>
#       <th id="T_2739d_level1_row3" class="row_heading level1 row3" >got</th>
#       <td id="T_2739d_row3_col0" class="data row3 col0" >2.667 ± 2.082</td>
#       <td id="T_2739d_row3_col1" class="data row3 col1" >0.938 ± 0.067</td>
#       <td id="T_2739d_row3_col2" class="data row3 col2" >0.003 ± 0.005</td>
#       <td id="T_2739d_row3_col3" class="data row3 col3" >0.188 ± 0.196</td>
#       <td id="T_2739d_row3_col4" class="data row3 col4" >0.194 ± 0.289</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exp 3: Controlling the first iteration reward function

# %%
# Get the fewshot=True and evaluator=vit
exp3_df = result[(result['pe'] != 'io') & (result['evaluator'] == 'vit')]
exp3_df.groupby(experiment_cols_without_seed).count()
# Out:
#                        seed  Max Similarity Iteration  Max Similarity  \
# pe  evaluator fewshot
# cot vit       False       3                         3               3
#               True        3                         3               3
# got vit       False       3                         3               3
#               True        3                         3               3
# tot vit       False       3                         3               3
#               True        3                         3               3
#
#                        Diversity at Max Similarity  \
# pe  evaluator fewshot
# cot vit       False                              3
#               True                               3
# got vit       False                              3
#               True                               3
# tot vit       False                              3
#               True                               3
#
#                        Max Normalized Similarity Iteration  \
# pe  evaluator fewshot
# cot vit       False                                      3
#               True                                       3
# got vit       False                                      3
#               True                                       3
# tot vit       False                                      3
#               True                                       3
#
#                        Max Normalized Similarity  \
# pe  evaluator fewshot
# cot vit       False                            3
#               True                             3
# got vit       False                            3
#               True                             3
# tot vit       False                            3
#               True                             3
#
#                        Diversity at Max Normalized Similarity  \
# pe  evaluator fewshot
# cot vit       False                                         3
#               True                                          3
# got vit       False                                         3
#               True                                          3
# tot vit       False                                         3
#               True                                          3
#
#                        Final Iteration  Final Similarity  Final Diversity  \
# pe  evaluator fewshot
# cot vit       False                  3                 3                3
#               True                   3                 3                3
# got vit       False                  3                 3                3
#               True                   3                 3                3
# tot vit       False                  3                 3                3
#               True                   3                 3                3
#
#                        Final Normalized Similarity  Final Normalized Diversity
# pe  evaluator fewshot
# cot vit       False                              3                           3
#               True                               3                           3
# got vit       False                              3                           3
#               True                               3                           3
# tot vit       False                              3                           3
#               True                               3                           3

# %%
exp3_df.groupby(experiment_cols_without_seed).agg(plotter)
# Out:
#                       Max Normalized Similarity            \
#                                            mean       std
# pe  evaluator fewshot
# cot vit       False                    0.977454  0.021648
#               True                     0.916787  0.057077
# got vit       False                    0.937511  0.067052
#               True                     0.933643  0.060379
# tot vit       False                    0.993376  0.011363
#               True                     0.922666  0.067673
#
#                       Diversity at Max Normalized Similarity            \
#                                                         mean       std
# pe  evaluator fewshot
# cot vit       False                                 0.000276  0.000276
#               True                                  0.001381  0.002308
# got vit       False                                 0.002784  0.004822
#               True                                  0.003584  0.005928
# tot vit       False                                 0.000018  0.000031
#               True                                  0.000177  0.000307
#
#                       Max Similarity Iteration            \
#                                           mean       std
# pe  evaluator fewshot
# cot vit       False                   2.666667  0.577350
#               True                    3.000000  2.645751
# got vit       False                   2.666667  2.081666
#               True                    2.333333  2.309401
# tot vit       False                   4.000000  2.645751
#               True                    1.000000  0.000000
#
#                       Final Normalized Similarity            \
#                                              mean       std
# pe  evaluator fewshot
# cot vit       False                      0.349105  0.559748
#               True                       0.336769  0.558513
# got vit       False                      0.188280  0.196360
#               True                       0.259426  0.393623
# tot vit       False                      0.341161  0.465834
#               True                       0.035057  0.050085
#
#                       Final Normalized Diversity
#                                             mean       std
# pe  evaluator fewshot
# cot vit       False                     0.345809  0.300050
#               True                      0.292813  0.304952
# got vit       False                     0.194201  0.288931
#               True                      0.110371  0.161636
# tot vit       False                     0.479615  0.436744
#               True                      0.457707  0.131691

# %%
# Short the dataframe with fewshot True is on top
exp3_df = exp3_df.sort_values(by='fewshot', ascending=True)
print_result_table(exp3_df, category_columns=['pe', 'fewshot'])
# Out:
# <style type="text/css">
# #T_574f9 caption {
#   font-size: 16px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_574f9 th {
#   text-align: center;
# }
# #T_574f9 td {
#   text-align: center;
# }
# #T_574f9_row0_col0, #T_574f9_row0_col1, #T_574f9_row0_col2, #T_574f9_row0_col3, #T_574f9_row0_col4, #T_574f9_row1_col0, #T_574f9_row1_col1, #T_574f9_row1_col2, #T_574f9_row1_col3, #T_574f9_row1_col4, #T_574f9_row2_col0, #T_574f9_row2_col1, #T_574f9_row2_col2, #T_574f9_row2_col3, #T_574f9_row2_col4, #T_574f9_row3_col0, #T_574f9_row3_col1, #T_574f9_row3_col2, #T_574f9_row3_col3, #T_574f9_row3_col4, #T_574f9_row4_col0, #T_574f9_row4_col1, #T_574f9_row4_col2, #T_574f9_row4_col3, #T_574f9_row4_col4, #T_574f9_row5_col0, #T_574f9_row5_col1, #T_574f9_row5_col2, #T_574f9_row5_col3, #T_574f9_row5_col4 {
#   text-align: center;
#   border: 1px solid black;
# }
# </style>
# <table id="T_574f9">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Iteration Type</th>
#       <th id="T_574f9_level0_col0" class="col_heading level0 col0" colspan="3">Best Similarity Iteration (Mean ± Std)</th>
#       <th id="T_574f9_level0_col3" class="col_heading level0 col3" colspan="2">Final Iteration (Mean ± Std)</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_574f9_level1_col0" class="col_heading level1 col0" >Iteration</th>
#       <th id="T_574f9_level1_col1" class="col_heading level1 col1" >Similarity</th>
#       <th id="T_574f9_level1_col2" class="col_heading level1 col2" >Diversity</th>
#       <th id="T_574f9_level1_col3" class="col_heading level1 col3" >Similarity</th>
#       <th id="T_574f9_level1_col4" class="col_heading level1 col4" >Diversity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pe</th>
#       <th class="index_name level1" >fewshot</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_574f9_level0_row0" class="row_heading level0 row0" rowspan="2">cot</th>
#       <th id="T_574f9_level1_row0" class="row_heading level1 row0" >False</th>
#       <td id="T_574f9_row0_col0" class="data row0 col0" >2.667 ± 0.577</td>
#       <td id="T_574f9_row0_col1" class="data row0 col1" >0.977 ± 0.022</td>
#       <td id="T_574f9_row0_col2" class="data row0 col2" >0.000 ± 0.000</td>
#       <td id="T_574f9_row0_col3" class="data row0 col3" >0.349 ± 0.560</td>
#       <td id="T_574f9_row0_col4" class="data row0 col4" >0.346 ± 0.300</td>
#     </tr>
#     <tr>
#       <th id="T_574f9_level1_row1" class="row_heading level1 row1" >True</th>
#       <td id="T_574f9_row1_col0" class="data row1 col0" >3.000 ± 2.646</td>
#       <td id="T_574f9_row1_col1" class="data row1 col1" >0.917 ± 0.057</td>
#       <td id="T_574f9_row1_col2" class="data row1 col2" >0.001 ± 0.002</td>
#       <td id="T_574f9_row1_col3" class="data row1 col3" >0.337 ± 0.559</td>
#       <td id="T_574f9_row1_col4" class="data row1 col4" >0.293 ± 0.305</td>
#     </tr>
#     <tr>
#       <th id="T_574f9_level0_row2" class="row_heading level0 row2" rowspan="2">tot</th>
#       <th id="T_574f9_level1_row2" class="row_heading level1 row2" >False</th>
#       <td id="T_574f9_row2_col0" class="data row2 col0" >4.000 ± 2.646</td>
#       <td id="T_574f9_row2_col1" class="data row2 col1" >0.993 ± 0.011</td>
#       <td id="T_574f9_row2_col2" class="data row2 col2" >0.000 ± 0.000</td>
#       <td id="T_574f9_row2_col3" class="data row2 col3" >0.341 ± 0.466</td>
#       <td id="T_574f9_row2_col4" class="data row2 col4" >0.480 ± 0.437</td>
#     </tr>
#     <tr>
#       <th id="T_574f9_level1_row3" class="row_heading level1 row3" >True</th>
#       <td id="T_574f9_row3_col0" class="data row3 col0" >1.000 ± 0.000</td>
#       <td id="T_574f9_row3_col1" class="data row3 col1" >0.923 ± 0.068</td>
#       <td id="T_574f9_row3_col2" class="data row3 col2" >0.000 ± 0.000</td>
#       <td id="T_574f9_row3_col3" class="data row3 col3" >0.035 ± 0.050</td>
#       <td id="T_574f9_row3_col4" class="data row3 col4" >0.458 ± 0.132</td>
#     </tr>
#     <tr>
#       <th id="T_574f9_level0_row4" class="row_heading level0 row4" rowspan="2">got</th>
#       <th id="T_574f9_level1_row4" class="row_heading level1 row4" >False</th>
#       <td id="T_574f9_row4_col0" class="data row4 col0" >2.667 ± 2.082</td>
#       <td id="T_574f9_row4_col1" class="data row4 col1" >0.938 ± 0.067</td>
#       <td id="T_574f9_row4_col2" class="data row4 col2" >0.003 ± 0.005</td>
#       <td id="T_574f9_row4_col3" class="data row4 col3" >0.188 ± 0.196</td>
#       <td id="T_574f9_row4_col4" class="data row4 col4" >0.194 ± 0.289</td>
#     </tr>
#     <tr>
#       <th id="T_574f9_level1_row5" class="row_heading level1 row5" >True</th>
#       <td id="T_574f9_row5_col0" class="data row5 col0" >2.333 ± 2.309</td>
#       <td id="T_574f9_row5_col1" class="data row5 col1" >0.934 ± 0.060</td>
#       <td id="T_574f9_row5_col2" class="data row5 col2" >0.004 ± 0.006</td>
#       <td id="T_574f9_row5_col3" class="data row5 col3" >0.259 ± 0.394</td>
#       <td id="T_574f9_row5_col4" class="data row5 col4" >0.110 ± 0.162</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Appendix: Additional Analysis
